# %%
import pathlib
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
from matplotlib import gridspec
import pandas as pd
import pingouin as pg
import seaborn as sns


import TwoPUtils as tpu
import STX3KO_analyses as stx
from STX3KO_analyses import utilities as u

ko_mice = stx.ymaze_sess_deets.ko_mice
ctrl_mice = stx.ymaze_sess_deets.ctrl_mice
sparse_mice = stx.ymaze_sess_deets.sparse_mice

plt.rcParams['pdf.fonttype']=42


# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sess = u.load_single_day(ctrl_mice[0],0)
sess_vr = u.load_vr_day(ctrl_mice[0],0, pkldir = '/mnt/BigDisk/YMaze_VR_Pkls')
# Out:
# {'date': '29_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3, 'novel_arm': -1, 'ravel_ind': 0}
# {'date': '29_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3, 'novel_arm': -1, 'ravel_ind': 0}

# %%
licks = sess.trial_matrices['licks'][sess.trial_info['LR']!=sess.novel_arm,:]
licks_vr = sess_vr.trial_matrices['licks_sum'][sess_vr.trial_info['LR']!=sess_vr.novel_arm, :]
sess.trial_matrices['licks_sum'] = sess_vr.trial_matrices['licks_sum']

# %%
fig, ax = plt.subplots()
ax.plot(np.nanmean(licks,axis=0))
ax.plot(np.nanmean(licks_vr, axis=0))
