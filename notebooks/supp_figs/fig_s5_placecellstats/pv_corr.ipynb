# %%
import pathlib

import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import pandas as pd
import pingouin as pg

import STX3KO_analyses as stx
from STX3KO_analyses import utilities as u
import TwoPUtils as tpu

ko_mice = stx.ymaze_sess_deets.ko_mice
ctrl_mice = stx.ymaze_sess_deets.ctrl_mice
sparse_mice = stx.ymaze_sess_deets.sparse_mice


plt.rcParams['pdf.fonttype']=42
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
figdir = pathlib.Path('/mnt/BigDisk/fig_scratch/stx3/figS5_pv_corr')
figdir.mkdir(exist_ok=True, parents=True)

# %%
mouse = ctrl_mice[0]
day = 0
ttype= 'fam'

# %%
# fraction of cells that are place cells dense
rows = []
for cond, mice in zip(('ctrl','ko'), (ctrl_mice, ko_mice)):
    for mouse in mice:
        for day in range(6):

            sess = u.load_single_day(mouse,day)

            for ttype in ('fam','nov'):

                if ttype=='fam':
                    tmask = sess.trial_info['LR']!=sess.novel_arm
                else:
                    tmask = sess.trial_info['LR']==sess.novel_arm

                trial_mat = sess.trial_matrices['F_dff'][tmask, : ,:]

                pvcorr = stx.spatial_analyses.calc_pv_corr(trial_mat)
                pvcorr[np.diag_indices_from(pvcorr)]=np.nan
                mu_pvcorr = np.nanmean(pvcorr.ravel())
                rows.append({
                    'cond': cond,
                    'mouse': mouse,
                    'day': day,
                    'nov': ttype,
                    'pvcorr': mu_pvcorr,
                })
df = pd.DataFrame(rows)
# Out:
# {'date': '29_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3, 'novel_arm': -1, 'ravel_ind': 0}
# /home/mplitt/mambaforge/envs/stx3/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/mplitt/mambaforge/envs/stx3/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# {'date': '30_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 7, 'novel_arm': -1, 'ravel_ind': 1}
# /home/mplitt/mambaforge/envs/stx3/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/mplitt/mambaforge/envs/stx3/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# ...

# %%
fig, ax = plt.subplots(1,2, figsize=[9,3])

for i, ttype in enumerate(('fam', 'nov')):
    tmp_df = df.loc[df['nov']==ttype]

    if ttype == 'fam':
        marker='.'
        s=8
    else:
        marker='P'
        s=8

    sns.stripplot(
        data=tmp_df,
        x='day',
        y='pvcorr',
        hue='cond',
        dodge=True,
        ax=ax[i],
        palette=['black','red'],
        hue_order=['ctrl','ko'],
        alpha=1., marker=marker, s=s,
    )

    sns.pointplot(
        data=tmp_df,
        x='day',
        y='pvcorr',
        hue='cond',
        dodge=.4,
        ax=ax[i],
        palette=['black','red'],
        hue_order=['ctrl','ko'],
        errorbar=None,
        linestyles="none",
        marker="_", markersize=15, markeredgewidth=5, legend=False, alpha=.4,
    )
    ax[i].set_title(ttype)


for a in ax.flatten():
    a.spines['top'].set_visible(False)
    a.spines['right'].set_visible(False)

fig.savefig(figdir / "dense_pvcorr_v_days.pdf")

# %%
# fraction of cells that are place cells dense
rows = []
for cond, mice in zip(('ctrl','ko'), (ctrl_mice, ko_mice)):
    for mouse in mice:
        for day in range(6):

            sess = u.load_single_day(mouse,day)

            fam_mask = sess.trial_info['LR']!=sess.novel_arm
            nov_mask = sess.trial_info['LR']==sess.novel_arm

            fam_mat = np.nanmean(sess.trial_matrices['F_dff'][fam_mask,10:,:], axis=0)
            nov_mat = np.nanmean(sess.trial_matrices['F_dff'][nov_mask, 10:, :], axis=0)

            fam_mat[np.isnan(fam_mat)]=0
            nov_mat[np.isnan(nov_mat)]=0

            corr_mat = np.zeros((fam_mat.shape[0],))
            for pos in range(fam_mat.shape[0]):
                corr_mat[pos] = np.corrcoef(np.vstack((fam_mat[pos,:], nov_mat[pos,:])))[0,1]

            rows.append({
                'cond': cond,
                'mouse': mouse,
                'day': day,
                'pvcorr': corr_mat.mean(),
            })
df = pd.DataFrame(rows)
# Out:
# {'date': '29_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3, 'novel_arm': -1, 'ravel_ind': 0}
# {'date': '30_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 7, 'novel_arm': -1, 'ravel_ind': 1}
# {'date': '01_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4, 'novel_arm': -1, 'ravel_ind': 2}
# {'date': '02_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3, 'novel_arm': -1, 'ravel_ind': 3}
# {'date': '03_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 8, 'novel_arm': -1, 'ravel_ind': 4}
# {'date': '04_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 2, 'novel_arm': -1, 'ravel_ind': 5}
# {'date': '29_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4, 'novel_arm': 1, 'ravel_ind': 0}
# {'date': '30_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4, 'novel_arm': 1, 'ravel_ind': 1}
# {'date': '01_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4, 'novel_arm': 1, 'ravel_ind': 2}
# ...

# %%
fig, ax = plt.subplots(figsize=[4.5,3])


sns.stripplot(
    data=tmp_df,
    x='day',
    y='pvcorr',
    hue='cond',
    dodge=True,
    ax=ax,
    palette=['black','red'],
    hue_order=['ctrl','ko'],
    alpha=1., 
)

sns.pointplot(
    data=tmp_df,
    x='day',
    y='pvcorr',
    hue='cond',
    dodge=.4,
    ax=ax,
    palette=['black','red'],
    hue_order=['ctrl','ko'],
    errorbar=None,
    linestyles="none",
    marker="_", markersize=15, markeredgewidth=5, legend=False, alpha=.4,
)


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig(figdir / "dense_acrosstttype_pvcorr_v_days.pdf")

# %%
# fraction of cells that are place cells dense
rows = []
for mouse in sparse_mice:
    for day in range(6):
        if mouse=='SparseKO_09' and day==2:
            continue

        sess = u.load_single_day(mouse,day)
        for chan in ('channel_0', 'channel_1'):
            for ttype in ('fam','nov'):

                if ttype=='fam':
                    tmask = sess.trial_info['LR']!=sess.novel_arm
                else:
                    tmask = sess.trial_info['LR']==sess.novel_arm

                trial_mat = sess.trial_matrices[f'{chan}_F_dff'][tmask, : ,:]
                trial_mat[np.isnan(trial_mat)]=0

                pvcorr = stx.spatial_analyses.calc_pv_corr(trial_mat)
                pvcorr[np.diag_indices_from(pvcorr)]=np.nan
                mu_pvcorr = np.nanmean(pvcorr.ravel())
                rows.append({
                    'chan': chan,
                    'mouse': mouse,
                    'day': day,
                    'ttype': ttype,
                    'pvcorr': mu_pvcorr,
                })
df = pd.DataFrame(rows)
# Out:
# {'date': '16_11_2024', 'scene': 'YMaze_LNovel', 'session': 4, 'scan': 14, 'novel_arm': -1, 'exp_day': 1}
# /home/mplitt/mambaforge/envs/stx3/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/mplitt/mambaforge/envs/stx3/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# {'date': '17_11_2024', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 25, 'novel_arm': -1, 'exp_day': 2}
# /home/mplitt/mambaforge/envs/stx3/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/mplitt/mambaforge/envs/stx3/lib/python3.10/site-packages/numpy/lib/_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# ...

# %%
fig, ax = plt.subplots(1,2, figsize=[9,3])

for i, ttype in enumerate(('fam', 'nov')):
    tmp_df = df.loc[df['ttype']==ttype]
    if ttype == 'fam':
        marker='.'
        s=12
    else:
        marker='P'
        s=8
    sns.stripplot(
        data=tmp_df,
        x='day',
        y='pvcorr',
        hue='chan',
        dodge=True,
        ax=ax[i],
        palette=['black','red'],
        hue_order=['channel_1','channel_0'],
        alpha=1., legend=False, marker=marker, s=s,
    )

    
    ax[i].set_title(ttype)
    for d in range(0,12,2):
        for (x0, y0), (x1, y1) in zip(ax[i].collections[d].get_offsets(), ax[i].collections[d+1].get_offsets()):
            ax[i].plot([x0, x1], [y0, y1], color='black', ls=':', zorder=0)

for a in ax.flatten():
    a.spines['top'].set_visible(False)
    a.spines['right'].set_visible(False)

fig.savefig(figdir / "sparse_pvcorr_v_days.pdf")

# %%
df.loc[df['day']==3]
# Out:
#           chan        mouse  day ttype    pvcorr
# 12   channel_0  SparseKO_02    3   fam  0.555341
# 13   channel_0  SparseKO_02    3   nov  0.543555
# 14   channel_1  SparseKO_02    3   fam  0.481299
# 15   channel_1  SparseKO_02    3   nov  0.431163
# 36   channel_0  SparseKO_06    3   fam  0.384590
# 37   channel_0  SparseKO_06    3   nov  0.411027
# 38   channel_1  SparseKO_06    3   fam  0.386376
# 39   channel_1  SparseKO_06    3   nov  0.374852
# 60   channel_0  SparseKO_08    3   fam  0.367910
# 61   channel_0  SparseKO_08    3   nov  0.300435
# 62   channel_1  SparseKO_08    3   fam  0.458749
# 63   channel_1  SparseKO_08    3   nov  0.396856
# 84   channel_0  SparseKO_10    3   fam  0.353374
# 85   channel_0  SparseKO_10    3   nov  0.434812
# 86   channel_1  SparseKO_10    3   fam  0.362911
# 87   channel_1  SparseKO_10    3   nov  0.330512
# 108  channel_0  SparseKO_11    3   fam  0.433913
# 109  channel_0  SparseKO_11    3   nov  0.425957
# ...

# %%
# fraction of cells that are place cells dense
rows = []

for mouse in sparse_mice:
    for day in range(6):
        if mouse == 'SparseKO_09' and day ==2:
            continue

        sess = u.load_single_day(mouse,day)

        fam_mask = sess.trial_info['LR']!=sess.novel_arm
        nov_mask = sess.trial_info['LR']==sess.novel_arm

        for chan in ('channel_0', 'channel_1'):

            fam_mat = np.nanmean(sess.trial_matrices[f'{chan}_F_dff'][fam_mask,10:,:], axis=0)
            nov_mat = np.nanmean(sess.trial_matrices[f'{chan}_F_dff'][nov_mask, 10:, :], axis=0)

            fam_mat[np.isnan(fam_mat)]=0
            nov_mat[np.isnan(nov_mat)]=0

            corr_mat = np.zeros((fam_mat.shape[0],))
            for pos in range(fam_mat.shape[0]):
                corr_mat[pos] = np.corrcoef(np.vstack((fam_mat[pos,:], nov_mat[pos,:])))[0,1]

            rows.append({
                'chan': chan,
                'mouse': mouse,
                'day': day,
                'pvcorr': corr_mat.mean(),
            })
df = pd.DataFrame(rows)
# Out:
# {'date': '16_11_2024', 'scene': 'YMaze_LNovel', 'session': 4, 'scan': 14, 'novel_arm': -1, 'exp_day': 1}
# {'date': '17_11_2024', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 25, 'novel_arm': -1, 'exp_day': 2}
# {'date': '18_11_2024', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 18, 'novel_arm': -1, 'exp_day': 3}
# {'date': '19_11_2024', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4, 'novel_arm': -1, 'exp_day': 4}
# {'date': '20_11_2024', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 12, 'novel_arm': -1, 'exp_day': 5}
# {'date': '21_11_2024', 'scene': 'YMaze_LNovel', 'session': 2, 'scan': 8, 'novel_arm': -1, 'exp_day': 6}
# {'date': '26_05_2025', 'scene': 'YMaze_LNovel', 'session': 4, 'scan': 7, 'novel_arm': 1, 'exp_day': 1}
# {'date': '27_05_2025', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 23, 'novel_arm': 1, 'exp_day': 2}
# {'date': '28_05_2025', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 25, 'novel_arm': 1, 'exp_day': 3}
# ...

# %%
fig, ax = plt.subplots( figsize=[4.5,3])


sns.stripplot(
    data=tmp_df,
    x='day',
    y='pvcorr',
    hue='chan',
    dodge=True,
    ax=ax,
    palette=['black','red'],
    hue_order=['channel_1','channel_0'],
    alpha=1., legend=False, marker=marker, s=s,
)


ax.set_title(ttype)
for d in range(0,12,2):
    for (x0, y0), (x1, y1) in zip(ax.collections[d].get_offsets(), ax.collections[d+1].get_offsets()):
        ax.plot([x0, x1], [y0, y1], color='black', ls=':', zorder=0)


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig(figdir / "sparse_acrossttype_pvcorr_v_days.pdf")
