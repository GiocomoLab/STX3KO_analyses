# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
source_folder  = os.path.join('/media','mplitt','Backup Plus1','2P_Data')
write_folder = os.path.join('/mnt','BigDisk','2P_scratch')


mouse = '4467332.1'

file_list = ({'date': '29_11_2020', 'scene':'YMaze_LNovel','session':1,'scan':8},
             {'date': '30_11_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '01_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':5},
             {'date': '02_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':6},
             {'date': '03_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '04_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':2},
             {'date': '05_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3}, 
             {'date':'05_12_2020','scene':'YMaze_RewardReversal', 'session':1,'scan':5},
             {'date': '06_12_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':1},
             {'date': '07_12_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':2}, 
             {'date':'07_12_2020','scene':'YMaze_LNovel', 'session':1,'scan':5})

# %%
def check_and_make_h5s(file_list,runh5=True):
    h5list, framerates = [], []
    for f in file_list:
        print(f)
        scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
        try:
            source_folder  = os.path.join('/media','mplitt','Backup Plus3','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        except:
            source_folder  = os.path.join('/media','mplitt','Backup Plus5')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        
        file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
        h5path = os.path.join(file_stem,scan_str+".h5")
        if not os.path.exists(h5path) and runh5:
            _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)

        h5list.append(file_stem)
        framerates.append(info['frame_rate'])
    print(h5list)
    return h5list, framerates

# %%
_file_list = ({'date': '29_11_2020', 'scene':'YMaze_LNovel','session':1,'scan':8},
             {'date': '30_11_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '01_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':5},
             {'date': '02_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':6},
             {'date': '03_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '04_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':2},
             )


for f in _file_list:
    _h5list,_frs = check_and_make_h5s([f,])
    ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                                   'save_path0': _h5list[0],
                                    'fast_disk':[],
                                    'move_bin':True,
                                    'two_step_registration':True,
                                    'maxregshiftNR':10,
                                    'nchannels':2,
                                    'tau':.7,
                                    'functional_chan':1,
                                    'fs':_frs[0],
                                    'roidetect':True,
                                    'input_format':"h5",
                                    'h5py_key':'data',
                                    'nchannels':2,
                                    'threshold_scaling':1.,
                                    'chan2_thresh':.01})
    ops=s2p.run_s2p(ops=ops)
    # !rm {_h5list[0]}/*.h5
# Out:
# {'date': '29_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 8}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 34154
# ['/mnt/BigDisk/2P_scratch/4467332.1/29_11_2020/YMaze_LNovel/YMaze_LNovel_001_008']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/29_11_2020/YMaze_LNovel/YMaze_LNovel_001_008/YMaze_LNovel_001_008.h5']
# time 1885.58 sec. Wrote 34154 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 34154 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 18.02 sec.
# Registered 2000/34154 in 82.69s
# Registered 4000/34154 in 176.17s
# Registered 6000/34154 in 269.91s
# Registered 8000/34154 in 365.30s
# Registered 10000/34154 in 459.76s
# Registered 12000/34154 in 550.82s
# Registered 14000/34154 in 645.16s
# Registered 16000/34154 in 739.53s
# Registered 18000/34154 in 828.71s
# Registered 20000/34154 in 919.75s
# Registered 22000/34154 in 1006.93s
# Registered 24000/34154 in 1092.20s
# Registered 26000/34154 in 1184.71s
# Registered 28000/34154 in 1275.62s
# Registered 30000/34154 in 1364.89s
# Registered 32000/34154 in 1456.36s
# Registered 34000/34154 in 1549.23s
# Registered second channel in 810.53 sec.
# ----------- Total 2394.63 sec
# Registration metrics, 43.37 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3039,416,694], 299.87 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.53, threshold 25.33
# 0 ROIs, score=402.73
# 1000 ROIs, score=74.69
# 2000 ROIs, score=37.94
# Found 2565 ROIs, 107.52 sec
# After removing overlaps, 2322 ROIs remain
# Masks made in 74.54 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 567.07 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2322 ROIs in 34154 frames, 522.45 sec.
# Extracted fluorescence from 2322 ROIs in 34154 frames, 524.51 sec.
# added enhanced mean image
# ----------- Total 1072.74 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.37 sec.
# Plane 0 processed in 4085.91 sec (can open in GUI).
# total = 5973.03 sec.
# TOTAL RUNTIME 5973.03 sec
# {'date': '30_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 37689
# ['/mnt/BigDisk/2P_scratch/4467332.1/30_11_2020/YMaze_LNovel/YMaze_LNovel_001_004']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/30_11_2020/YMaze_LNovel/YMaze_LNovel_001_004/YMaze_LNovel_001_004.h5']
# time 2076.26 sec. Wrote 37689 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 37689 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 17.88 sec.
# Registered 2000/37689 in 96.70s
# Registered 4000/37689 in 187.31s
# Registered 6000/37689 in 273.59s
# Registered 8000/37689 in 355.62s
# Registered 10000/37689 in 439.77s
# Registered 12000/37689 in 535.98s
# Registered 14000/37689 in 630.10s
# Registered 16000/37689 in 726.63s
# Registered 18000/37689 in 823.40s
# Registered 20000/37689 in 918.79s
# Registered 22000/37689 in 1014.02s
# Registered 24000/37689 in 1111.37s
# Registered 26000/37689 in 1207.16s
# Registered 28000/37689 in 1305.78s
# Registered 30000/37689 in 1391.97s
# Registered 32000/37689 in 1486.46s
# Registered 34000/37689 in 1588.65s
# Registered 36000/37689 in 1693.32s
# Registered 37689/37689 in 1781.68s
# Registered second channel in 1258.99 sec.
# ----------- Total 3070.88 sec
# Registration metrics, 61.00 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3355,416,694], 418.91 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.80, threshold 27.96
# 0 ROIs, score=454.71
# 1000 ROIs, score=75.89
# 2000 ROIs, score=30.67
# Found 2088 ROIs, 115.91 sec
# After removing overlaps, 1956 ROIs remain
# Masks made in 45.86 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 635.32 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1956 ROIs in 37689 frames, 599.45 sec.
# Extracted fluorescence from 1956 ROIs in 37689 frames, 667.83 sec.
# added enhanced mean image
# ----------- Total 1288.88 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.13 sec.
# Plane 0 processed in 5065.88 sec (can open in GUI).
# total = 7144.56 sec.
# TOTAL RUNTIME 7144.56 sec
# {'date': '01_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 5}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 35533
# ['/mnt/BigDisk/2P_scratch/4467332.1/01_12_2020/YMaze_LNovel/YMaze_LNovel_001_005']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/01_12_2020/YMaze_LNovel/YMaze_LNovel_001_005/YMaze_LNovel_001_005.h5']
# time 2849.93 sec. Wrote 35533 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 35533 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 19.84 sec.
# Registered 2000/35533 in 112.48s
# Registered 4000/35533 in 220.11s
# Registered 6000/35533 in 332.04s
# Registered 8000/35533 in 438.03s
# Registered 10000/35533 in 550.41s
# Registered 12000/35533 in 649.02s
# Registered 14000/35533 in 739.82s
# Registered 16000/35533 in 837.02s
# Registered 18000/35533 in 952.82s
# Registered 20000/35533 in 1066.73s
# Registered 22000/35533 in 1186.81s
# Registered 24000/35533 in 1298.87s
# Registered 26000/35533 in 1418.63s
# Registered 28000/35533 in 1510.44s
# Registered 30000/35533 in 1603.95s
# Registered 32000/35533 in 1712.07s
# Registered 34000/35533 in 1815.20s
# Registered 35533/35533 in 1893.40s
# Registered second channel in 1276.22 sec.
# ----------- Total 3203.88 sec
# Registration metrics, 85.94 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3171,416,694], 547.88 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.64, threshold 26.43
# 0 ROIs, score=409.10
# 1000 ROIs, score=56.54
# Found 1732 ROIs, 89.85 sec
# After removing overlaps, 1660 ROIs remain
# Masks made in 32.47 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 708.82 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1660 ROIs in 35533 frames, 621.19 sec.
# Extracted fluorescence from 1660 ROIs in 35533 frames, 607.82 sec.
# added enhanced mean image
# ----------- Total 1265.13 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.25 sec.
# Plane 0 processed in 5271.58 sec (can open in GUI).
# total = 8126.89 sec.
# TOTAL RUNTIME 8126.89 sec
# {'date': '02_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 6}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 32239
# ['/mnt/BigDisk/2P_scratch/4467332.1/02_12_2020/YMaze_LNovel/YMaze_LNovel_001_006']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/02_12_2020/YMaze_LNovel/YMaze_LNovel_001_006/YMaze_LNovel_001_006.h5']
# time 2538.58 sec. Wrote 32239 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 32239 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 19.45 sec.
# Registered 2000/32239 in 113.63s
# Registered 4000/32239 in 223.68s
# Registered 6000/32239 in 329.89s
# Registered 8000/32239 in 435.71s
# Registered 10000/32239 in 542.07s
# Registered 12000/32239 in 644.95s
# Registered 14000/32239 in 748.52s
# Registered 16000/32239 in 843.19s
# Registered 18000/32239 in 950.47s
# Registered 20000/32239 in 1068.38s
# Registered 22000/32239 in 1182.20s
# Registered 24000/32239 in 1302.97s
# Registered 26000/32239 in 1419.01s
# Registered 28000/32239 in 1514.65s
# Registered 30000/32239 in 1615.05s
# Registered 32000/32239 in 1715.22s
# Registered second channel in 929.88 sec.
# ----------- Total 2688.13 sec
# Registration metrics, 55.75 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2854,416,694], 300.10 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.38, threshold 23.78
# 0 ROIs, score=453.84
# 1000 ROIs, score=54.40
# Found 1747 ROIs, 81.01 sec
# After removing overlaps, 1660 ROIs remain
# Masks made in 31.25 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 450.25 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1660 ROIs in 32239 frames, 334.82 sec.
# Extracted fluorescence from 1660 ROIs in 32239 frames, 379.56 sec.
# added enhanced mean image
# ----------- Total 741.96 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.91 sec.
# Plane 0 processed in 3944.40 sec (can open in GUI).
# total = 6489.61 sec.
# TOTAL RUNTIME 6489.61 sec
# {'date': '03_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 30325
# ['/mnt/BigDisk/2P_scratch/4467332.1/03_12_2020/YMaze_LNovel/YMaze_LNovel_001_003']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/03_12_2020/YMaze_LNovel/YMaze_LNovel_001_003/YMaze_LNovel_001_003.h5']
# time 1809.21 sec. Wrote 30325 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 30325 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 20.67 sec.
# Registered 2000/30325 in 114.66s
# Registered 4000/30325 in 227.38s
# Registered 6000/30325 in 342.36s
# Registered 8000/30325 in 457.91s
# Registered 10000/30325 in 574.53s
# Registered 12000/30325 in 691.20s
# Registered 14000/30325 in 794.81s
# Registered 16000/30325 in 900.49s
# Registered 18000/30325 in 1009.58s
# Registered 20000/30325 in 1123.97s
# Registered 22000/30325 in 1235.50s
# Registered 24000/30325 in 1342.04s
# Registered 26000/30325 in 1433.51s
# Registered 28000/30325 in 1526.16s
# Registered 30000/30325 in 1633.57s
# Registered second channel in 702.27 sec.
# ----------- Total 2390.63 sec
# Registration metrics, 83.30 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2680,416,694], 395.50 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.23, threshold 22.33
# 0 ROIs, score=368.20
# 1000 ROIs, score=50.55
# Found 1802 ROIs, 84.19 sec
# After removing overlaps, 1722 ROIs remain
# Masks made in 34.18 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 555.17 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1722 ROIs in 30325 frames, 440.96 sec.
# Extracted fluorescence from 1722 ROIs in 30325 frames, 313.76 sec.
# added enhanced mean image
# ----------- Total 776.26 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.84 sec.
# Plane 0 processed in 3809.75 sec (can open in GUI).
# total = 5620.24 sec.
# TOTAL RUNTIME 5620.24 sec
# {'date': '04_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 2}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 29019
# ['/mnt/BigDisk/2P_scratch/4467332.1/04_12_2020/YMaze_LNovel/YMaze_LNovel_001_002']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/04_12_2020/YMaze_LNovel/YMaze_LNovel_001_002/YMaze_LNovel_001_002.h5']
# time 1429.27 sec. Wrote 29019 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 29019 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 19.90 sec.
# Registered 2000/29019 in 98.09s
# Registered 4000/29019 in 196.78s
# Registered 6000/29019 in 292.12s
# Registered 8000/29019 in 387.53s
# Registered 10000/29019 in 479.70s
# Registered 12000/29019 in 571.05s
# Registered 14000/29019 in 662.43s
# Registered 16000/29019 in 753.58s
# Registered 18000/29019 in 849.22s
# Registered 20000/29019 in 939.96s
# Registered 22000/29019 in 1031.33s
# Registered 24000/29019 in 1121.82s
# Registered 26000/29019 in 1212.65s
# Registered 28000/29019 in 1297.42s
# Registered second channel in 527.41 sec.
# ----------- Total 1894.50 sec
# Registration metrics, 60.46 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2592,416,694], 318.25 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.16, threshold 21.60
# 0 ROIs, score=445.03
# 1000 ROIs, score=51.48
# Found 1679 ROIs, 80.61 sec
# After removing overlaps, 1592 ROIs remain
# Masks made in 30.66 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 466.90 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1592 ROIs in 29019 frames, 305.04 sec.
# Extracted fluorescence from 1592 ROIs in 29019 frames, 301.64 sec.
# added enhanced mean image
# ----------- Total 626.36 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.61 sec.
# Plane 0 processed in 3051.83 sec (can open in GUI).
# total = 4481.94 sec.
# TOTAL RUNTIME 4481.94 sec

# %%
_file_list = ({'date': '05_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3}, 
             {'date':'05_12_2020','scene':'YMaze_RewardReversal', 'session':1,'scan':5},)

_h5list,_frs = check_and_make_h5s(_file_list)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"05_12_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':1.,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '05_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 9371
# {'date': '05_12_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 5}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 26275
# ['/mnt/BigDisk/2P_scratch/4467332.1/05_12_2020/YMaze_LNovel/YMaze_LNovel_001_003', '/mnt/BigDisk/2P_scratch/4467332.1/05_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_005']
# {}
# h5
# ** Found 2 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/05_12_2020/YMaze_LNovel/YMaze_LNovel_001_003/YMaze_LNovel_001_003.h5', '/mnt/BigDisk/2P_scratch/4467332.1/05_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_005/YMaze_RewardReversal_001_005.h5']
# time 1889.84 sec. Wrote 35646 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 35646 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 18.88 sec.
# Registered 2000/35646 in 89.89s
# Registered 4000/35646 in 179.06s
# Registered 6000/35646 in 267.27s
# Registered 8000/35646 in 356.31s
# Registered 10000/35646 in 455.74s
# Registered 12000/35646 in 558.73s
# Registered 14000/35646 in 661.53s
# Registered 16000/35646 in 766.10s
# Registered 18000/35646 in 869.61s
# Registered 20000/35646 in 964.31s
# Registered 22000/35646 in 1058.54s
# Registered 24000/35646 in 1151.75s
# Registered 26000/35646 in 1244.38s
# Registered 28000/35646 in 1339.36s
# Registered 30000/35646 in 1424.99s
# Registered 32000/35646 in 1513.41s
# Registered 34000/35646 in 1608.57s
# Registered 35646/35646 in 1687.17s
# Registered second channel in 671.74 sec.
# ----------- Total 2387.72 sec
# Registration metrics, 62.38 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3182,416,694], 317.91 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.65, threshold 26.52
# 0 ROIs, score=538.60
# 1000 ROIs, score=65.71
# Found 1842 ROIs, 95.82 sec
# After removing overlaps, 1743 ROIs remain
# Masks made in 37.60 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 496.43 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1743 ROIs in 35646 frames, 380.76 sec.
# Extracted fluorescence from 1743 ROIs in 35646 frames, 393.78 sec.
# added enhanced mean image
# ----------- Total 795.81 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.43 sec.
# Plane 0 processed in 3749.37 sec (can open in GUI).
# total = 5641.37 sec.
# TOTAL RUNTIME 5641.37 sec

# %%
_file_list = ({'date': '07_12_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':2}, 
             {'date':'07_12_2020','scene':'YMaze_LNovel', 'session':1,'scan':5})

_h5list,_frs = check_and_make_h5s(_file_list)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"07_12_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':1.,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '07_12_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 2}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 8931
# {'date': '07_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 5}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 25823
# ['/mnt/BigDisk/2P_scratch/4467332.1/07_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_002', '/mnt/BigDisk/2P_scratch/4467332.1/07_12_2020/YMaze_LNovel/YMaze_LNovel_001_005']
# {}
# h5
# ** Found 2 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/07_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_002/YMaze_RewardReversal_001_002.h5', '/mnt/BigDisk/2P_scratch/4467332.1/07_12_2020/YMaze_LNovel/YMaze_LNovel_001_005/YMaze_LNovel_001_005.h5']
# time 1617.30 sec. Wrote 34754 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 34754 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 18.18 sec.
# Registered 2000/34754 in 102.19s
# Registered 4000/34754 in 193.68s
# Registered 6000/34754 in 289.52s
# Registered 8000/34754 in 384.13s
# Registered 10000/34754 in 476.56s
# Registered 12000/34754 in 571.93s
# Registered 14000/34754 in 667.44s
# Registered 16000/34754 in 759.97s
# Registered 18000/34754 in 850.70s
# Registered 20000/34754 in 946.43s
# Registered 22000/34754 in 1029.32s
# Registered 24000/34754 in 1119.40s
# Registered 26000/34754 in 1217.18s
# Registered 28000/34754 in 1313.25s
# Registered 30000/34754 in 1406.15s
# Registered 32000/34754 in 1501.09s
# Registered 34000/34754 in 1598.50s
# Registered second channel in 622.35 sec.
# ----------- Total 2287.81 sec
# Registration metrics, 45.90 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3091,416,694], 297.66 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.58, threshold 25.76
# 0 ROIs, score=628.45
# 1000 ROIs, score=64.59
# Found 1764 ROIs, 91.18 sec
# After removing overlaps, 1656 ROIs remain
# Masks made in 33.95 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 464.13 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1656 ROIs in 34754 frames, 356.06 sec.
# Extracted fluorescence from 1656 ROIs in 34754 frames, 364.15 sec.
# added enhanced mean image
# ----------- Total 738.86 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.38 sec.
# Plane 0 processed in 3543.16 sec (can open in GUI).
# total = 5162.18 sec.
# TOTAL RUNTIME 5162.18 sec
