# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
write_folder = os.path.join('/home/mplitt','2P_scratch')
s2p_write_folder = os.path.join('/home/mplitt','2P_scratch')

mouse = '4467975.5'

file_list = ({'date': '28_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '29_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '30_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':5},
             {'date': '01_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':7},
             {'date': '02_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '03_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':5},
             {'date': '04_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '04_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':8},
             {'date': '05_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':3},
             {'date': '06_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':5},
             {'date': '06_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':9},
             )

# %%
def check_and_make_h5s(file_list, runh5=True):
    h5list, framerates = [], []
    for f in file_list:
        print(f)
        scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
        try:
            source_folder  = os.path.join('/media','mplitt','Backup Plus','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        except:
            source_folder  = os.path.join('/media','mplitt','Backup Plus1','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        
        file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
        h5path = os.path.join(file_stem,scan_str+".h5")
        if not os.path.exists(h5path) and runh5:
            _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)

        h5list.append(file_stem)
        framerates.append(info['frame_rate'])
    print(h5list)
    return h5list, framerates

# %%
h5list_all, frs_all = check_and_make_h5s(file_list)
ops = TwoPUtils.s2p.set_ops(d={'data_path': h5list_all,
                               'save_path0': os.path.join(s2p_write_folder,mouse,"YMazeAll"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':frs_all[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'saveNWB':True,
                                'threshold_scaling':.9,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)

# %%
_file_list = ({'date': '28_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '29_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '30_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':5},
             {'date': '01_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':7},
             {'date': '02_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '03_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':5},
             {'date': '05_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':3},
             )

for f in _file_list:
    _h5list,_frs = check_and_make_h5s([f,])
    ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                                   'save_path0': _h5list[0],
                                    'fast_disk':[],
                                    'move_bin':True,
                                    'two_step_registration':True,
                                    'maxregshiftNR':10,
                                    'nchannels':2,
                                    'tau':.7,
                                    'functional_chan':1,
                                    'fs':_frs[0],
                                    'roidetect':True,
                                    'input_format':"h5",
                                    'h5py_key':'data',
                                    'nchannels':2,
                                    'threshold_scaling':1.5,
                                    'chan2_thresh':.01})
    ops=s2p.run_s2p(ops=ops)
    # !rm {_h5list[0]}/*.h5
# Out:
# {'date': '28_09_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 39204
# ['/home/mplitt/2P_scratch/4467975.5/28_09_2020/YMaze_LNovel/YMaze_LNovel_001_004']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467975.5/28_09_2020/YMaze_LNovel/YMaze_LNovel_001_004/YMaze_LNovel_001_004.h5']
# time 365.37 sec. Wrote 39204 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 39204 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 20.66 sec.
# Registered 2000/39204 in 82.24s
# Registered 4000/39204 in 166.03s
# Registered 6000/39204 in 258.88s
# Registered 8000/39204 in 342.03s
# Registered 10000/39204 in 432.04s
# Registered 12000/39204 in 520.99s
# Registered 14000/39204 in 609.79s
# Registered 16000/39204 in 699.07s
# Registered 18000/39204 in 789.38s
# Registered 20000/39204 in 879.10s
# Registered 22000/39204 in 964.95s
# Registered 24000/39204 in 1045.58s
# Registered 26000/39204 in 1126.73s
# Registered 28000/39204 in 1206.42s
# Registered 30000/39204 in 1286.58s
# Registered 32000/39204 in 1366.11s
# Registered 34000/39204 in 1445.29s
# Registered 36000/39204 in 1526.78s
# Registered 38000/39204 in 1611.11s
# Registered second channel in 293.07 sec.
# ----------- Total 1981.42 sec
# Registration metrics, 29.59 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3489,416,694], 86.11 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.91, threshold 21.81
# 0 ROIs, score=540.26
# 1000 ROIs, score=68.49
# 2000 ROIs, score=30.85
# Found 2457 ROIs, 99.88 sec
# After removing overlaps, 2259 ROIs remain
# Masks made in 57.26 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 310.62 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2259 ROIs in 39204 frames, 228.13 sec.
# Extracted fluorescence from 2259 ROIs in 39204 frames, 232.22 sec.
# added enhanced mean image
# ----------- Total 468.02 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 6.04 sec.
# Plane 0 processed in 2796.99 sec (can open in GUI).
# total = 3163.46 sec.
# TOTAL RUNTIME 3163.46 sec
# {'date': '29_09_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 39641
# ['/home/mplitt/2P_scratch/4467975.5/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_003']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467975.5/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_003/YMaze_LNovel_001_003.h5']
# time 317.53 sec. Wrote 39641 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 39641 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 18.34 sec.
# Registered 2000/39641 in 75.53s
# Registered 4000/39641 in 151.73s
# Registered 6000/39641 in 228.33s
# Registered 8000/39641 in 304.71s
# Registered 10000/39641 in 379.60s
# Registered 12000/39641 in 457.43s
# Registered 14000/39641 in 533.49s
# Registered 16000/39641 in 610.85s
# Registered 18000/39641 in 686.53s
# Registered 20000/39641 in 763.15s
# Registered 22000/39641 in 838.91s
# Registered 24000/39641 in 914.32s
# Registered 26000/39641 in 988.07s
# Registered 28000/39641 in 1062.25s
# Registered 30000/39641 in 1136.62s
# Registered 32000/39641 in 1210.29s
# Registered 34000/39641 in 1285.00s
# Registered 36000/39641 in 1368.94s
# Registered 38000/39641 in 1445.55s
# Registered 39641/39641 in 1508.34s
# Registered second channel in 265.53 sec.
# ----------- Total 1798.28 sec
# Registration metrics, 28.44 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3537,416,694], 92.89 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.95, threshold 22.11
# 0 ROIs, score=536.69
# 1000 ROIs, score=71.30
# 2000 ROIs, score=32.83
# Found 2525 ROIs, 114.33 sec
# After removing overlaps, 2329 ROIs remain
# Masks made in 62.90 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 343.89 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2329 ROIs in 39641 frames, 217.02 sec.
# Extracted fluorescence from 2329 ROIs in 39641 frames, 210.63 sec.
# added enhanced mean image
# ----------- Total 435.32 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.73 sec.
# Plane 0 processed in 2613.23 sec (can open in GUI).
# total = 2932.03 sec.
# TOTAL RUNTIME 2932.03 sec
# {'date': '30_09_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 5}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 40000
# 40000 40733
# ['/home/mplitt/2P_scratch/4467975.5/30_09_2020/YMaze_LNovel/YMaze_LNovel_001_005']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467975.5/30_09_2020/YMaze_LNovel/YMaze_LNovel_001_005/YMaze_LNovel_001_005.h5']
# time 374.46 sec. Wrote 40733 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 40733 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 19.00 sec.
# Registered 2000/40733 in 82.95s
# Registered 4000/40733 in 204.87s
# Registered 6000/40733 in 321.11s
# Registered 8000/40733 in 410.48s
# Registered 10000/40733 in 498.23s
# Registered 12000/40733 in 586.50s
# Registered 14000/40733 in 682.95s
# Registered 16000/40733 in 780.85s
# Registered 18000/40733 in 867.97s
# Registered 20000/40733 in 950.71s
# Registered 22000/40733 in 1036.77s
# Registered 24000/40733 in 1121.35s
# Registered 26000/40733 in 1207.29s
# Registered 28000/40733 in 1294.79s
# Registered 30000/40733 in 1381.50s
# Registered 32000/40733 in 1459.94s
# Registered 34000/40733 in 1537.33s
# Registered 36000/40733 in 1615.05s
# Registered 38000/40733 in 1691.15s
# Registered 40000/40733 in 1768.29s
# Registered second channel in 272.67 sec.
# ----------- Total 2094.81 sec
# Registration metrics, 25.15 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3622,416,694], 88.74 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 3.02, threshold 22.64
# 0 ROIs, score=584.00
# 1000 ROIs, score=65.12
# 2000 ROIs, score=33.23
# Found 2549 ROIs, 105.73 sec
# After removing overlaps, 2364 ROIs remain
# Masks made in 56.18 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 313.53 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2364 ROIs in 40733 frames, 176.92 sec.
# Extracted fluorescence from 2364 ROIs in 40733 frames, 172.80 sec.
# added enhanced mean image
# ----------- Total 356.27 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.40 sec.
# Plane 0 processed in 2796.42 sec (can open in GUI).
# total = 3172.00 sec.
# TOTAL RUNTIME 3172.00 sec
# {'date': '01_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 7}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 39457
# ['/home/mplitt/2P_scratch/4467975.5/01_10_2020/YMaze_LNovel/YMaze_LNovel_001_007']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467975.5/01_10_2020/YMaze_LNovel/YMaze_LNovel_001_007/YMaze_LNovel_001_007.h5']
# time 389.24 sec. Wrote 39457 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 39457 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 23.85 sec.
# Registered 2000/39457 in 85.54s
# Registered 4000/39457 in 171.78s
# Registered 6000/39457 in 258.44s
# Registered 8000/39457 in 345.30s
# Registered 10000/39457 in 432.51s
# Registered 12000/39457 in 520.57s
# Registered 14000/39457 in 610.51s
# Registered 16000/39457 in 701.54s
# Registered 18000/39457 in 789.48s
# Registered 20000/39457 in 877.96s
# Registered 22000/39457 in 965.60s
# Registered 24000/39457 in 1050.95s
# Registered 26000/39457 in 1138.97s
# Registered 28000/39457 in 1227.71s
# Registered 30000/39457 in 1319.21s
# Registered 32000/39457 in 1407.85s
# Registered 34000/39457 in 1496.61s
# Registered 36000/39457 in 1584.64s
# Registered 38000/39457 in 1670.42s
# Registered second channel in 298.91 sec.
# ----------- Total 2061.27 sec
# Registration metrics, 29.45 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3491,416,694], 100.48 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.91, threshold 21.82
# 0 ROIs, score=528.75
# 1000 ROIs, score=69.01
# 2000 ROIs, score=31.34
# Found 2470 ROIs, 117.22 sec
# After removing overlaps, 2271 ROIs remain
# Masks made in 63.32 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 364.35 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2271 ROIs in 39457 frames, 275.25 sec.
# Extracted fluorescence from 2271 ROIs in 39457 frames, 220.18 sec.
# added enhanced mean image
# ----------- Total 503.52 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.86 sec.
# Plane 0 processed in 2965.76 sec (can open in GUI).
# total = 3356.31 sec.
# TOTAL RUNTIME 3356.31 sec
# {'date': '02_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 40000
# 40000 41000
# 41000 42000
# 42000 42197
# ['/home/mplitt/2P_scratch/4467975.5/02_10_2020/YMaze_LNovel/YMaze_LNovel_001_003']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467975.5/02_10_2020/YMaze_LNovel/YMaze_LNovel_001_003/YMaze_LNovel_001_003.h5']
# time 347.95 sec. Wrote 42197 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 42197 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 18.75 sec.
# Registered 2000/42197 in 77.30s
# Registered 4000/42197 in 152.84s
# Registered 6000/42197 in 227.75s
# Registered 8000/42197 in 302.78s
# Registered 10000/42197 in 377.25s
# Registered 12000/42197 in 451.33s
# Registered 14000/42197 in 526.27s
# Registered 16000/42197 in 600.79s
# Registered 18000/42197 in 675.87s
# Registered 20000/42197 in 755.26s
# Registered 22000/42197 in 837.17s
# Registered 24000/42197 in 917.80s
# Registered 26000/42197 in 1001.54s
# Registered 28000/42197 in 1083.25s
# Registered 30000/42197 in 1165.01s
# Registered 32000/42197 in 1255.53s
# Registered 34000/42197 in 1346.10s
# Registered 36000/42197 in 1436.10s
# Registered 38000/42197 in 1525.53s
# Registered 40000/42197 in 1614.96s
# Registered 42000/42197 in 1706.35s
# Registered second channel in 328.27 sec.
# ----------- Total 2068.81 sec
# Registration metrics, 29.83 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3757,416,694], 106.45 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 3.13, threshold 23.48
# 0 ROIs, score=559.79
# 1000 ROIs, score=62.93
# 2000 ROIs, score=28.05
# Found 2257 ROIs, 128.67 sec
# After removing overlaps, 2111 ROIs remain
# Masks made in 48.04 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 341.51 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2111 ROIs in 42197 frames, 221.61 sec.
# Extracted fluorescence from 2111 ROIs in 42197 frames, 224.36 sec.
# added enhanced mean image
# ----------- Total 453.13 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.60 sec.
# Plane 0 processed in 2900.49 sec (can open in GUI).
# total = 3249.70 sec.
# TOTAL RUNTIME 3249.70 sec
# {'date': '03_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 5}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 39412
# ['/home/mplitt/2P_scratch/4467975.5/03_10_2020/YMaze_LNovel/YMaze_LNovel_001_005']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467975.5/03_10_2020/YMaze_LNovel/YMaze_LNovel_001_005/YMaze_LNovel_001_005.h5']
# time 364.21 sec. Wrote 39412 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 39412 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 20.03 sec.
# Registered 2000/39412 in 80.18s
# Registered 4000/39412 in 162.92s
# Registered 6000/39412 in 244.05s
# Registered 8000/39412 in 324.69s
# Registered 10000/39412 in 406.64s
# Registered 12000/39412 in 487.94s
# Registered 14000/39412 in 569.76s
# Registered 16000/39412 in 652.33s
# Registered 18000/39412 in 731.44s
# Registered 20000/39412 in 806.03s
# Registered 22000/39412 in 880.79s
# Registered 24000/39412 in 956.19s
# Registered 26000/39412 in 1034.44s
# Registered 28000/39412 in 1109.67s
# Registered 30000/39412 in 1183.05s
# Registered 32000/39412 in 1257.45s
# Registered 34000/39412 in 1331.64s
# Registered 36000/39412 in 1405.85s
# Registered 38000/39412 in 1479.75s
# Registered second channel in 255.79 sec.
# ----------- Total 1814.84 sec
# Registration metrics, 26.52 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3488,416,694], 82.33 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.91, threshold 21.80
# 0 ROIs, score=650.21
# 1000 ROIs, score=81.14
# 2000 ROIs, score=40.42
# Found 2880 ROIs, 113.23 sec
# After removing overlaps, 2592 ROIs remain
# Masks made in 76.06 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 358.30 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2592 ROIs in 39412 frames, 179.54 sec.
# Extracted fluorescence from 2592 ROIs in 39412 frames, 175.79 sec.
# added enhanced mean image
# ----------- Total 361.94 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.62 sec.
# Plane 0 processed in 2568.51 sec (can open in GUI).
# total = 2933.73 sec.
# TOTAL RUNTIME 2933.73 sec
# {'date': '05_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 3}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 39000
# 39000 39303
# ['/home/mplitt/2P_scratch/4467975.5/05_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_003']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467975.5/05_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_003/YMaze_RewardReversal_001_003.h5']
# time 354.81 sec. Wrote 39303 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 39303 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 20.08 sec.
# Registered 2000/39303 in 77.52s
# Registered 4000/39303 in 155.35s
# Registered 6000/39303 in 233.58s
# Registered 8000/39303 in 311.56s
# Registered 10000/39303 in 389.07s
# Registered 12000/39303 in 466.96s
# Registered 14000/39303 in 551.72s
# Registered 16000/39303 in 632.52s
# Registered 18000/39303 in 720.85s
# Registered 20000/39303 in 805.46s
# Registered 22000/39303 in 887.74s
# Registered 24000/39303 in 969.56s
# Registered 26000/39303 in 1053.95s
# Registered 28000/39303 in 1153.89s
# Registered 30000/39303 in 1235.71s
# Registered 32000/39303 in 1322.87s
# Registered 34000/39303 in 1412.54s
# Registered 36000/39303 in 1501.76s
# Registered 38000/39303 in 1594.06s
# Registered second channel in 313.92 sec.
# ----------- Total 1993.41 sec
# Registration metrics, 33.14 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3492,416,694], 93.42 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.91, threshold 21.83
# 0 ROIs, score=521.43
# 1000 ROIs, score=78.00
# 2000 ROIs, score=37.44
# Found 2831 ROIs, 126.59 sec
# After removing overlaps, 2497 ROIs remain
# Masks made in 81.63 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 392.46 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2497 ROIs in 39303 frames, 195.45 sec.
# Extracted fluorescence from 2497 ROIs in 39303 frames, 187.05 sec.
# added enhanced mean image
# ----------- Total 389.25 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.39 sec.
# Plane 0 processed in 2814.91 sec (can open in GUI).
# total = 3170.73 sec.
# TOTAL RUNTIME 3170.74 sec

# %%
_file_list = ({'date': '04_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '04_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':8},)

_h5list,_frs = check_and_make_h5s(_file_list)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"04_10_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':1.5,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '04_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 10897
# {'date': '04_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 8}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 28140
# ['/home/mplitt/2P_scratch/4467975.5/04_10_2020/YMaze_LNovel/YMaze_LNovel_001_004', '/home/mplitt/2P_scratch/4467975.5/04_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_008']
# {}
# h5
# ** Found 2 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467975.5/04_10_2020/YMaze_LNovel/YMaze_LNovel_001_004/YMaze_LNovel_001_004.h5', '/home/mplitt/2P_scratch/4467975.5/04_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_008/YMaze_RewardReversal_001_008.h5']
# time 347.18 sec. Wrote 39037 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 39037 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 21.16 sec.
# Registered 2000/39037 in 77.58s
# Registered 4000/39037 in 151.34s
# Registered 6000/39037 in 225.27s
# Registered 8000/39037 in 299.13s
# Registered 10000/39037 in 372.98s
# Registered 12000/39037 in 447.13s
# Registered 14000/39037 in 521.55s
# Registered 16000/39037 in 595.96s
# Registered 18000/39037 in 669.80s
# Registered 20000/39037 in 744.47s
# Registered 22000/39037 in 818.69s
# Registered 24000/39037 in 896.63s
# Registered 26000/39037 in 979.46s
# Registered 28000/39037 in 1060.65s
# Registered 30000/39037 in 1142.21s
# Registered 32000/39037 in 1225.03s
# Registered 34000/39037 in 1306.41s
# Registered 36000/39037 in 1388.34s
# Registered 38000/39037 in 1470.90s
# Registered second channel in 277.61 sec.
# ----------- Total 1819.52 sec
# Registration metrics, 27.73 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3510,416,694], 91.18 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.92, threshold 21.94
# 0 ROIs, score=591.22
# 1000 ROIs, score=77.04
# 2000 ROIs, score=39.45
# Found 2886 ROIs, 120.65 sec
# After removing overlaps, 2601 ROIs remain
# Masks made in 77.33 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 376.35 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2601 ROIs in 39037 frames, 204.76 sec.
# Extracted fluorescence from 2601 ROIs in 39037 frames, 205.33 sec.
# added enhanced mean image
# ----------- Total 416.97 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 6.10 sec.
# Plane 0 processed in 2648.01 sec (can open in GUI).
# total = 2996.73 sec.
# TOTAL RUNTIME 2996.73 sec

# %%
_file_list = ({'date': '06_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':5},
             {'date': '06_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':9},)

_h5list,_frs = check_and_make_h5s(_file_list)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"06_10_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':1.5,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '06_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 5}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 10896
# {'date': '06_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 9}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 27113
# ['/home/mplitt/2P_scratch/4467975.5/06_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_005', '/home/mplitt/2P_scratch/4467975.5/06_10_2020/YMaze_LNovel/YMaze_LNovel_001_009']
# {}
# h5
# ** Found 2 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467975.5/06_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_005/YMaze_RewardReversal_001_005.h5', '/home/mplitt/2P_scratch/4467975.5/06_10_2020/YMaze_LNovel/YMaze_LNovel_001_009/YMaze_LNovel_001_009.h5']
# time 350.00 sec. Wrote 38009 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 38009 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 28.53 sec.
# Registered 2000/38009 in 84.01s
# Registered 4000/38009 in 168.99s
# Registered 6000/38009 in 261.18s
# Registered 8000/38009 in 353.91s
# Registered 10000/38009 in 443.19s
# Registered 12000/38009 in 534.28s
# Registered 14000/38009 in 629.34s
# Registered 16000/38009 in 720.64s
# Registered 18000/38009 in 813.76s
# Registered 20000/38009 in 901.32s
# Registered 22000/38009 in 982.09s
# Registered 24000/38009 in 1064.35s
# Registered 26000/38009 in 1146.06s
# Registered 28000/38009 in 1227.91s
# Registered 30000/38009 in 1307.82s
# Registered 32000/38009 in 1380.29s
# Registered 34000/38009 in 1453.48s
# Registered 36000/38009 in 1529.31s
# Registered 38000/38009 in 1604.83s
# Registered second channel in 254.10 sec.
# ----------- Total 1895.71 sec
# Registration metrics, 27.21 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3405,416,694], 83.89 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.84, threshold 21.28
# 0 ROIs, score=562.52
# 1000 ROIs, score=71.67
# 2000 ROIs, score=36.98
# Found 2905 ROIs, 107.23 sec
# After removing overlaps, 2606 ROIs remain
# Masks made in 65.42 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 332.28 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2606 ROIs in 38009 frames, 167.37 sec.
# Extracted fluorescence from 2606 ROIs in 38009 frames, 161.43 sec.
# added enhanced mean image
# ----------- Total 335.27 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.45 sec.
# Plane 0 processed in 2597.16 sec (can open in GUI).
# total = 2948.12 sec.
# TOTAL RUNTIME 2948.12 sec

# %%
for h5 in h5list_all:
    # !rm {h5}/*.h5
