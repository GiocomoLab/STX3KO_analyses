# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
write_folder = os.path.join('/mnt','BigDisk','2P_scratch')


mouse = '4467975.2'

file_list = ({'date': '28_09_2020', 'scene':'YMaze_LNovel','session':3,'scan':8},
             {'date': '29_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '30_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '01_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '02_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':9},
             {'date': '03_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':8},
             {'date': '04_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':2},
             {'date': '04_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':5},
             {'date': '05_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':3},
             {'date': '06_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':5},
             {'date': '06_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':8},
             )

# %%
def check_and_make_h5s(file_list,runh5=True):
    h5list, framerates = [], []
    for f in file_list:
        print(f)
        scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
        try:
            source_folder  = os.path.join('/media','mplitt','Backup Plus','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        except:
            source_folder  = os.path.join('/media','mplitt','Backup Plus1','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        
        file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
        h5path = os.path.join(file_stem,scan_str+".h5")
        if not os.path.exists(h5path) and runh5:
            _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)

        h5list.append(file_stem)
        framerates.append(info['frame_rate'])
    print(h5list)
    return h5list, framerates

# %%
h5list_all, frs_all = check_and_make_h5s(file_list)
ops = TwoPUtils.s2p.set_ops(d={'data_path': h5list_all,
                               'save_path0': os.path.join(write_folder,mouse,"YMazeAll"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':frs_all[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'saveNWB':True,
                                'threshold_scaling':.9,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
# Out:
# {'date': '28_09_2020', 'scene': 'YMaze_LNovel', 'session': 3, 'scan': 8}
# {'date': '29_09_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# {'date': '30_09_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# {'date': '01_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# {'date': '02_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 9}
# {'date': '03_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 8}
# {'date': '04_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 2}
# {'date': '04_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 5}
# {'date': '05_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 3}
# {'date': '06_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 5}
# {'date': '06_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 8}
# ['/mnt/BigDisk/2P_scratch/4467975.2/28_09_2020/YMaze_LNovel/YMaze_LNovel_003_008', '/mnt/BigDisk/2P_scratch/4467975.2/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_003', '/mnt/BigDisk/2P_scratch/4467975.2/30_09_2020/YMaze_LNovel/YMaze_LNovel_001_004', '/mnt/BigDisk/2P_scratch/4467975.2/01_10_2020/YMaze_LNovel/YMaze_LNovel_001_004', '/mnt/BigDisk/2P_scratch/4467975.2/02_10_2020/YMaze_LNovel/YMaze_LNovel_001_009', '/mnt/BigDisk/2P_scratch/4467975.2/03_10_2020/YMaze_LNovel/YMaze_LNovel_001_008', '/mnt/BigDisk/2P_scratch/4467975.2/04_10_2020/YMaze_LNovel/YMaze_LNovel_001_002', '/mnt/BigDisk/2P_scratch/4467975.2/04_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001
sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 3.94, threshold 35.44
# 0 ROIs, score=351.51
# Found 479 ROIs, 74.58 sec
# After removing overlaps, 464 ROIs remain
# Masks made in 4.93 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 1593.48 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 464 ROIs in 337549 frames, 1481.92 sec.
# Extracted fluorescence from 464 ROIs in 337549 frames, 1484.30 sec.
# added enhanced mean image
# ----------- Total 2983.19 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 8.06 sec.
# Plane 0 processed in 20242.12 sec (can open in GUI).
# total = 27847.04 sec.
# TOTAL RUNTIME 27847.04 sec

# %%
_file_list = (#{'date': '28_09_2020', 'scene':'YMaze_LNovel','session':3,'scan':8},
             {'date': '29_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             #{'date': '30_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             #{'date': '01_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             #{'date': '02_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':9},
             #{'date': '03_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':8},
             #{'date': '05_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':3},
             )


for f in _file_list:
    _h5list,_frs = check_and_make_h5s([f,],runh5=False)
    ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                                   'save_path0': _h5list[0],
                                    'fast_disk':[],
                                    'move_bin':True,
                                    'two_step_registration':True,
                                    'maxregshiftNR':10,
                                    'nchannels':2,
                                    'tau':.7,
                                    'functional_chan':1,
                                    'fs':_frs[0],
                                    'roidetect':True,
                                    'input_format':"h5",
                                    'h5py_key':'data',
                                    'nchannels':2,
                                    'threshold_scaling':1.5,
                                    'chan2_thresh':.01})
    ops=s2p.run_s2p(ops=ops)
    # !rm {_h5list[0]}/*.h5
# Out:
# {'date': '29_09_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# ['/mnt/BigDisk/2P_scratch/4467975.2/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_003']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.2/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_003/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3410,416,694], 353.30 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.84, threshold 21.31
# 0 ROIs, score=544.03
# Found 728 ROIs, 87.95 sec
# After removing overlaps, 714 ROIs remain
# Masks made in 11.38 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 468.79 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 714 ROIs in 38188 frames, 300.59 sec.
# Extracted fluorescence from 714 ROIs in 38188 frames, 332.70 sec.
# added enhanced mean image
# ----------- Total 641.09 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.08 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.69 sec.
# Plane 0 processed in 1113.03 sec (can open in GUI).
# total = 1114.99 sec.
# TOTAL RUNTIME 1114.99 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.2/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_003/*.h5': No such file or directory

# %%
_file_list = ({'date': '04_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':2},
             {'date': '04_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':5},)

_h5list,_frs = check_and_make_h5s(_file_list,runh5=False)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"04_10_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':1.5,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '04_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 2}
# {'date': '04_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 5}
# ['/mnt/BigDisk/2P_scratch/4467975.2/04_10_2020/YMaze_LNovel/YMaze_LNovel_001_002', '/mnt/BigDisk/2P_scratch/4467975.2/04_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_005']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.2/04_10_2020/combined/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3280,416,694], 202.99 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.73, threshold 20.50
# 0 ROIs, score=466.91
# Found 541 ROIs, 55.18 sec
# After removing overlaps, 530 ROIs remain
# Masks made in 6.96 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 275.61 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 530 ROIs in 36999 frames, 203.50 sec.
# Extracted fluorescence from 530 ROIs in 36999 frames, 204.98 sec.
# added enhanced mean image
# ----------- Total 413.85 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.08 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 1.09 sec.
# Plane 0 processed in 690.91 sec (can open in GUI).
# total = 693.04 sec.
# TOTAL RUNTIME 693.04 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.2/04_10_2020/YMaze_LNovel/YMaze_LNovel_001_002/*.h5': No such file or directory
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.2/04_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_005/*.h5': No such file or directory

# %%
_file_list = ({'date': '06_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':5},
             {'date': '06_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':8},)

_h5list,_frs = check_and_make_h5s(_file_list,runh5=False)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"06_10_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':.8,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '06_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 5}
# {'date': '06_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 8}
# ['/mnt/BigDisk/2P_scratch/4467975.2/06_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_005', '/mnt/BigDisk/2P_scratch/4467975.2/06_10_2020/YMaze_LNovel/YMaze_LNovel_001_008']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.2/06_10_2020/combined/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3412,416,694], 310.64 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.84, threshold 22.75
# 0 ROIs, score=580.02
# Found 576 ROIs, 67.64 sec
# After removing overlaps, 562 ROIs remain
# Masks made in 8.53 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 398.14 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 562 ROIs in 38048 frames, 265.35 sec.
# Extracted fluorescence from 562 ROIs in 38048 frames, 341.02 sec.
# added enhanced mean image
# ----------- Total 624.60 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 1.92 sec.
# Plane 0 processed in 1024.90 sec (can open in GUI).
# total = 1027.16 sec.
# TOTAL RUNTIME 1027.16 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.2/06_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_005/*.h5': No such file or directory
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.2/06_10_2020/YMaze_LNovel/YMaze_LNovel_001_008/*.h5': No such file or directory

# %%
for h5 in h5list_all:
    # !rm {h5}/*.h5
