# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
write_folder = os.path.join('/mnt','BigDisk','2P_scratch')
s2p_write_folder = os.path.join('/home/mplitt','2P_scratch')

mouse = '4467975.3'

file_list = ({'date': '28_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '29_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '30_09_2020', 'scene':'YMaze_LNovel','session':2,'scan':7},
             {'date': '01_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':7},
             {'date': '02_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '03_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':6},
             {'date': '04_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '04_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':6},
             {'date': '05_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':3},
             {'date': '06_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':4},
             {'date': '06_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':8},
             )

# %%
def check_and_make_h5s(file_list,runh5=True):
    h5list, framerates = [], []
    for f in file_list:
        print(f)
        scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
        try:
            source_folder  = os.path.join('/media','mplitt','Backup Plus','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        except:
            source_folder  = os.path.join('/media','mplitt','Backup Plus1','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        
        file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
        h5path = os.path.join(file_stem,scan_str+".h5")
        if not os.path.exists(h5path) and runh5:
            _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)

        h5list.append(file_stem)
        framerates.append(info['frame_rate'])
    print(h5list)
    return h5list, framerates

# %%
h5list_all, frs_all = check_and_make_h5s(file_list)
ops = TwoPUtils.s2p.set_ops(d={'data_path': h5list_all,
                               'save_path0': os.path.join(write_folder,mouse,"YMazeAll"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':frs_all[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'saveNWB':True,
                                'threshold_scaling':.9,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
# Out:
# {'date': '28_09_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# {'date': '29_09_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# {'date': '30_09_2020', 'scene': 'YMaze_LNovel', 'session': 2, 'scan': 7}
# {'date': '01_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 7}
# {'date': '02_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# {'date': '03_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 6}
# {'date': '04_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# {'date': '04_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 6}
# {'date': '05_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 3}
# {'date': '06_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 4}
# {'date': '06_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 8}
# ['/mnt/BigDisk/2P_scratch/4467975.3/28_09_2020/YMaze_LNovel/YMaze_LNovel_001_004', '/mnt/BigDisk/2P_scratch/4467975.3/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_004', '/mnt/BigDisk/2P_scratch/4467975.3/30_09_2020/YMaze_LNovel/YMaze_LNovel_002_007', '/mnt/BigDisk/2P_scratch/4467975.3/01_10_2020/YMaze_LNovel/YMaze_LNovel_001_007', '/mnt/BigDisk/2P_scratch/4467975.3/02_10_2020/YMaze_LNovel/YMaze_LNovel_001_003', '/mnt/BigDisk/2P_scratch/4467975.3/03_10_2020/YMaze_LNovel/YMaze_LNovel_001_006', '/mnt/BigDisk/2P_scratch/4467975.3/04_10_2020/YMaze_LNovel/YMaze_LNovel_001_003', '/mnt/BigDisk/2P_scratch/4467975.3/04_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_006', '/mnt/BigDisk/2P_scratch/4467975.3/05_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_003', '/mnt/BigDisk/2P_scratch/4467975.3/06_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_004', '/mnt/BigDisk/2P_scratch/4467975.3/06_10_2020/YMaze_LNovel/YMaze_LNovel_001_008']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.3/YMazeAll/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 69
# Binned movie [4798,416,694], 1515.26 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 4.00, threshold 17.99
# 0 ROIs, score=516.97
# 1000 ROIs, score=137.56
# 2000 ROIs, score=76.59
# 3000 ROIs, score=49.37
# 4000 ROIs, score=34.61
# Found 5000 ROIs, 248.89 sec
# After removing overlaps, 3662 ROIs remain
# Masks made in 235.46 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 2246.42 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 3662 ROIs in 347793 frames, 2653.21 sec.
# Extracted fluorescence from 3662 ROIs in 347793 frames, 2661.21 sec.
# added enhanced mean image
# ----------- Total 5391.56 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.19 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 64.03 sec.
# Plane 0 processed in 7711.72 sec (can open in GUI).
# total = 7718.78 sec.
# TOTAL RUNTIME 7718.78 sec

# %%
_file_list = (#{'date': '28_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '29_09_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '30_09_2020', 'scene':'YMaze_LNovel','session':2,'scan':7},
             {'date': '01_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':7},
             {'date': '02_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '03_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':6},
             {'date': '05_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':3},
             )

for f in _file_list:
    _h5list,_frs = check_and_make_h5s([f,],runh5=False)
    ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                                   'save_path0': _h5list[0],
                                    'fast_disk':[],
                                    'move_bin':True,
                                    'two_step_registration':True,
                                    'maxregshiftNR':10,
                                    'nchannels':2,
                                    'tau':.7,
                                    'functional_chan':1,
                                    'fs':_frs[0],
                                    'roidetect':True,
                                    'input_format':"h5",
                                    'h5py_key':'data',
                                    'nchannels':2,
                                    'threshold_scaling':2.,
                                    'chan2_thresh':.01})
    ops=s2p.run_s2p(ops=ops)
    # !rm {_h5list[0]}/*.h5
# Out:
# {'date': '29_09_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# ['/mnt/BigDisk/2P_scratch/4467975.3/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_004']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.3/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_004/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3440,416,694], 315.51 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.87, threshold 28.67
# 0 ROIs, score=540.21
# 1000 ROIs, score=94.49
# 2000 ROIs, score=46.47
# Found 2723 ROIs, 109.95 sec
# After removing overlaps, 2469 ROIs remain
# Masks made in 54.70 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 544.38 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2469 ROIs in 38592 frames, 395.54 sec.
# Extracted fluorescence from 2469 ROIs in 38592 frames, 395.43 sec.
# added enhanced mean image
# ----------- Total 797.83 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.12 sec.
# Plane 0 processed in 1347.96 sec (can open in GUI).
# total = 1349.45 sec.
# TOTAL RUNTIME 1349.45 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/29_09_2020/YMaze_LNovel/YMaze_LNovel_001_004/*.h5': No such file or directory
# {'date': '30_09_2020', 'scene': 'YMaze_LNovel', 'session': 2, 'scan': 7}
# ['/mnt/BigDisk/2P_scratch/4467975.3/30_09_2020/YMaze_LNovel/YMaze_LNovel_002_007']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.3/30_09_2020/YMaze_LNovel/YMaze_LNovel_002_007/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3436,416,694], 327.42 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.86, threshold 28.63
# 0 ROIs, score=612.69
# 1000 ROIs, score=113.63
# 2000 ROIs, score=56.25
# 3000 ROIs, score=29.89
# Found 3067 ROIs, 119.69 sec
# After removing overlaps, 2685 ROIs remain
# Masks made in 69.05 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 597.46 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2685 ROIs in 38634 frames, 416.48 sec.
# Extracted fluorescence from 2685 ROIs in 38634 frames, 542.75 sec.
# added enhanced mean image
# ----------- Total 966.72 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 6.15 sec.
# Plane 0 processed in 1571.06 sec (can open in GUI).
# total = 1575.91 sec.
# TOTAL RUNTIME 1575.91 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/30_09_2020/YMaze_LNovel/YMaze_LNovel_002_007/*.h5': No such file or directory
# {'date': '01_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 7}
# ['/mnt/BigDisk/2P_scratch/4467975.3/01_10_2020/YMaze_LNovel/YMaze_LNovel_001_007']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.3/01_10_2020/YMaze_LNovel/YMaze_LNovel_001_007/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3442,416,694], 425.49 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.87, threshold 28.68
# 0 ROIs, score=554.54
# 1000 ROIs, score=90.72
# 2000 ROIs, score=42.73
# Found 2575 ROIs, 120.79 sec
# After removing overlaps, 2339 ROIs remain
# Masks made in 51.87 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 660.20 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2339 ROIs in 38676 frames, 479.72 sec.
# Extracted fluorescence from 2339 ROIs in 38676 frames, 402.27 sec.
# added enhanced mean image
# ----------- Total 888.95 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.93 sec.
# Plane 0 processed in 1554.73 sec (can open in GUI).
# total = 1558.91 sec.
# TOTAL RUNTIME 1558.91 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/01_10_2020/YMaze_LNovel/YMaze_LNovel_001_007/*.h5': No such file or directory
# {'date': '02_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# ['/mnt/BigDisk/2P_scratch/4467975.3/02_10_2020/YMaze_LNovel/YMaze_LNovel_001_003']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.3/02_10_2020/YMaze_LNovel/YMaze_LNovel_001_003/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3404,416,694], 322.85 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.84, threshold 28.37
# 0 ROIs, score=545.43
# 1000 ROIs, score=90.88
# 2000 ROIs, score=39.07
# Found 2424 ROIs, 105.92 sec
# After removing overlaps, 2169 ROIs remain
# Masks made in 44.18 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 528.71 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2169 ROIs in 38301 frames, 381.60 sec.
# Extracted fluorescence from 2169 ROIs in 38301 frames, 518.48 sec.
# added enhanced mean image
# ----------- Total 909.54 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.61 sec.
# Plane 0 processed in 1444.02 sec (can open in GUI).
# total = 1450.64 sec.
# TOTAL RUNTIME 1450.64 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/02_10_2020/YMaze_LNovel/YMaze_LNovel_001_003/*.h5': No such file or directory
# {'date': '03_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 6}
# ['/mnt/BigDisk/2P_scratch/4467975.3/03_10_2020/YMaze_LNovel/YMaze_LNovel_001_006']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.3/03_10_2020/YMaze_LNovel/YMaze_LNovel_001_006/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3442,416,694], 535.95 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.87, threshold 28.68
# 0 ROIs, score=642.46
# 1000 ROIs, score=109.69
# 2000 ROIs, score=50.46
# Found 2808 ROIs, 140.08 sec
# After removing overlaps, 2297 ROIs remain
# Masks made in 65.33 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 818.25 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2297 ROIs in 38928 frames, 567.04 sec.
# Extracted fluorescence from 2297 ROIs in 38928 frames, 560.28 sec.
# added enhanced mean image
# ----------- Total 1136.59 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.98 sec.
# Plane 0 processed in 1961.20 sec (can open in GUI).
# total = 1964.57 sec.
# TOTAL RUNTIME 1964.57 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/03_10_2020/YMaze_LNovel/YMaze_LNovel_001_006/*.h5': No such file or directory
# {'date': '05_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 3}
# ['/mnt/BigDisk/2P_scratch/4467975.3/05_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_003']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.3/05_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_003/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3482,416,694], 457.72 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.90, threshold 29.02
# 0 ROIs, score=565.70
# 1000 ROIs, score=99.09
# 2000 ROIs, score=42.47
# Found 2522 ROIs, 133.45 sec
# After removing overlaps, 2154 ROIs remain
# Masks made in 49.38 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 701.72 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2154 ROIs in 39026 frames, 502.12 sec.
# Extracted fluorescence from 2154 ROIs in 39026 frames, 522.61 sec.
# added enhanced mean image
# ----------- Total 1035.39 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.77 sec.
# Plane 0 processed in 1743.82 sec (can open in GUI).
# total = 1748.45 sec.
# TOTAL RUNTIME 1748.45 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/05_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_003/*.h5': No such file or directory

# %%
_file_list = ({'date': '04_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '04_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':6},)

_h5list,_frs = check_and_make_h5s(_file_list,runh5=False)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"04_10_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':1.5,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '04_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# {'date': '04_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 6}
# ['/mnt/BigDisk/2P_scratch/4467975.3/04_10_2020/YMaze_LNovel/YMaze_LNovel_001_003', '/mnt/BigDisk/2P_scratch/4467975.3/04_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_006']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.3/04_10_2020/combined/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3374,420,694], 387.57 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.81, threshold 42.17
# 0 ROIs, score=579.35
# 1000 ROIs, score=92.55
# Found 1785 ROIs, 90.83 sec
# After removing overlaps, 1688 ROIs remain
# Masks made in 30.34 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 547.80 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1688 ROIs in 37847 frames, 528.74 sec.
# Extracted fluorescence from 1688 ROIs in 37847 frames, 400.94 sec.
# added enhanced mean image
# ----------- Total 943.81 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.04 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.38 sec.
# Plane 0 processed in 1495.38 sec (can open in GUI).
# total = 1499.61 sec.
# TOTAL RUNTIME 1499.61 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/04_10_2020/YMaze_LNovel/YMaze_LNovel_001_003/*.h5': No such file or directory
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/04_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_006/*.h5': No such file or directory

# %%
_file_list = ({'date': '06_10_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':4},
             {'date': '06_10_2020', 'scene':'YMaze_LNovel','session':1,'scan':8},)

_h5list,_frs = check_and_make_h5s(_file_list,runh5=False)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"06_10_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':2.,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '06_10_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 4}
# {'date': '06_10_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 8}
# ['/mnt/BigDisk/2P_scratch/4467975.3/06_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_004', '/mnt/BigDisk/2P_scratch/4467975.3/06_10_2020/YMaze_LNovel/YMaze_LNovel_001_008']
# {}
# FOUND BINARIES AND OPS IN ['/mnt/BigDisk/2P_scratch/4467975.3/06_10_2020/combined/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3453,416,694], 446.75 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.88, threshold 28.77
# 0 ROIs, score=633.19
# 1000 ROIs, score=116.80
# 2000 ROIs, score=53.01
# Found 2893 ROIs, 133.99 sec
# After removing overlaps, 2320 ROIs remain
# Masks made in 71.00 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 729.83 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2320 ROIs in 38979 frames, 524.67 sec.
# Extracted fluorescence from 2320 ROIs in 38979 frames, 536.37 sec.
# added enhanced mean image
# ----------- Total 1072.09 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'skew', 'compact']
# ----------- Total 0.04 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.21 sec.
# Plane 0 processed in 1808.62 sec (can open in GUI).
# total = 1818.72 sec.
# TOTAL RUNTIME 1818.72 sec
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/06_10_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_004/*.h5': No such file or directory
# rm: cannot remove '/mnt/BigDisk/2P_scratch/4467975.3/06_10_2020/YMaze_LNovel/YMaze_LNovel_001_008/*.h5': No such file or directory

# %%
for h5 in h5list_all:
    # !rm {h5}/*.h5
