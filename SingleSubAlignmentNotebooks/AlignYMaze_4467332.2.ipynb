# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
source_folder  = os.path.join('/media','mplitt','Backup Plus1','2P_Data')
write_folder = os.path.join('/mnt','BigDisk','2P_scratch')


mouse = '4467332.2'

file_list = ({'date': '29_11_2020', 'scene':'YMaze_LNovel','session':1,'scan':14},
             {'date': '29_11_2020', 'scene':'YMaze_LNovel','session':2,'scan':18},
             {'date': '30_11_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '30_11_2020', 'scene':'YMaze_LNovel','session':3,'scan':9},
             {'date': '01_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '02_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '03_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '04_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '06_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3}, 
             {'date':'06_12_2020','scene':'YMaze_RewardReversal', 'session':1,'scan':6},
             {'date': '06_12_2020', 'scene':'YMaze_RewardReversal','session':2,'scan':2},
             {'date': '07_12_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':2}, 
             {'date':'07_12_2020','scene':'YMaze_LNovel', 'session':1,'scan':6})

# %%
def check_and_make_h5s(file_list,runh5=True):
    h5list, framerates = [], []
    for f in file_list:
        print(f)
        scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
        try:
            source_folder  = os.path.join('/media','mplitt','Backup Plus3','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        except:
            source_folder  = os.path.join('/media','mplitt','Backup Plus5')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        
        file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
        h5path = os.path.join(file_stem,scan_str+".h5")
        if not os.path.exists(h5path) and runh5:
            _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)

        h5list.append(file_stem)
        framerates.append(info['frame_rate'])
    print(h5list)
    return h5list, framerates

# %%
_file_list = ({'date': '29_11_2020', 'scene':'YMaze_LNovel','session':1,'scan':14},
             {'date': '29_11_2020', 'scene':'YMaze_LNovel','session':2,'scan':18},
             {'date': '30_11_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '30_11_2020', 'scene':'YMaze_LNovel','session':3,'scan':9},
             {'date': '01_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '02_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':4},
             {'date': '03_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '04_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3},
             {'date': '06_12_2020', 'scene':'YMaze_RewardReversal','session':2,'scan':2},
             )


for f in _file_list:
    _h5list,_frs = check_and_make_h5s([f,])
    ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                                   'save_path0': _h5list[0],
                                    'fast_disk':[],
                                    'move_bin':True,
                                    'two_step_registration':True,
                                    'maxregshiftNR':10,
                                    'nchannels':2,
                                    'tau':.7,
                                    'functional_chan':1,
                                    'fs':_frs[0],
                                    'roidetect':True,
                                    'input_format':"h5",
                                    'h5py_key':'data',
                                    'nchannels':2,
                                    'threshold_scaling':1.,
                                    'chan2_thresh':.01})
    ops=s2p.run_s2p(ops=ops)
    # !rm {_h5list[0]}/*.h5
# Out:
# {'date': '29_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 14}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 12725
# ['/mnt/BigDisk/2P_scratch/4467332.2/29_11_2020/YMaze_LNovel/YMaze_LNovel_001_014']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/29_11_2020/YMaze_LNovel/YMaze_LNovel_001_014/YMaze_LNovel_001_014.h5']
# time 1072.83 sec. Wrote 12725 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 12725 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 17.68 sec.
# Registered 2000/12725 in 124.74s
# Registered 4000/12725 in 223.22s
# Registered 6000/12725 in 315.28s
# Registered 8000/12725 in 421.65s
# Registered 10000/12725 in 539.27s
# Registered 12000/12725 in 654.79s
# Registered second channel in 517.46 sec.
# ----------- Total 1246.40 sec
# Registration metrics, 87.21 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1115,416,694], 236.31 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.00, threshold 10.00
# 0 ROIs, score=313.56
# 1000 ROIs, score=42.11
# 2000 ROIs, score=16.32
# Found 2568 ROIs, 46.89 sec
# After removing overlaps, 2199 ROIs remain
# Masks made in 72.89 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 441.79 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2199 ROIs in 12725 frames, 199.52 sec.
# Extracted fluorescence from 2199 ROIs in 12725 frames, 173.51 sec.
# added enhanced mean image
# ----------- Total 399.66 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 1.59 sec.
# Plane 0 processed in 2179.57 sec (can open in GUI).
# total = 3255.38 sec.
# TOTAL RUNTIME 3255.39 sec
# {'date': '29_11_2020', 'scene': 'YMaze_LNovel', 'session': 2, 'scan': 18}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 22651
# ['/mnt/BigDisk/2P_scratch/4467332.2/29_11_2020/YMaze_LNovel/YMaze_LNovel_002_018']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/29_11_2020/YMaze_LNovel/YMaze_LNovel_002_018/YMaze_LNovel_002_018.h5']
# time 1861.15 sec. Wrote 22651 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 22651 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 17.92 sec.
# Registered 2000/22651 in 118.98s
# Registered 4000/22651 in 240.65s
# Registered 6000/22651 in 360.75s
# Registered 8000/22651 in 473.22s
# Registered 10000/22651 in 597.73s
# Registered 12000/22651 in 721.40s
# Registered 14000/22651 in 849.81s
# Registered 16000/22651 in 973.95s
# Registered 18000/22651 in 1076.35s
# Registered 20000/22651 in 1175.22s
# Registered 22000/22651 in 1280.29s
# Registered second channel in 763.49 sec.
# ----------- Total 2106.45 sec
# Registration metrics, 89.50 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2014,416,694], 286.82 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.68, threshold 16.78
# 0 ROIs, score=461.12
# 1000 ROIs, score=57.72
# 2000 ROIs, score=25.08
# Found 2426 ROIs, 83.25 sec
# After removing overlaps, 2147 ROIs remain
# Masks made in 73.64 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 529.26 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2147 ROIs in 22651 frames, 296.04 sec.
# Extracted fluorescence from 2147 ROIs in 22651 frames, 299.48 sec.
# added enhanced mean image
# ----------- Total 616.50 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.04 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.85 sec.
# Plane 0 processed in 3348.15 sec (can open in GUI).
# total = 5212.85 sec.
# TOTAL RUNTIME 5212.85 sec
# {'date': '30_11_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 10164
# ['/mnt/BigDisk/2P_scratch/4467332.2/30_11_2020/YMaze_LNovel/YMaze_LNovel_001_004']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/30_11_2020/YMaze_LNovel/YMaze_LNovel_001_004/YMaze_LNovel_001_004.h5']
# time 838.11 sec. Wrote 10164 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 10164 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 17.86 sec.
# Registered 2000/10164 in 107.31s
# Registered 4000/10164 in 209.76s
# Registered 6000/10164 in 319.61s
# Registered 8000/10164 in 437.03s
# Registered 10000/10164 in 562.32s
# Registered second channel in 308.18 sec.
# ----------- Total 912.10 sec
# Registration metrics, 99.78 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [897,416,694], 184.35 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.00, threshold 10.00
# 0 ROIs, score=257.87
# 1000 ROIs, score=32.59
# 2000 ROIs, score=10.10
# Found 2017 ROIs, 36.01 sec
# After removing overlaps, 1825 ROIs remain
# Masks made in 46.45 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 321.60 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1825 ROIs in 10164 frames, 221.33 sec.
# Extracted fluorescence from 1825 ROIs in 10164 frames, 204.88 sec.
# added enhanced mean image
# ----------- Total 441.10 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 1.08 sec.
# Plane 0 processed in 1776.45 sec (can open in GUI).
# total = 2615.32 sec.
# TOTAL RUNTIME 2615.32 sec
# {'date': '30_11_2020', 'scene': 'YMaze_LNovel', 'session': 3, 'scan': 9}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 23026
# ['/mnt/BigDisk/2P_scratch/4467332.2/30_11_2020/YMaze_LNovel/YMaze_LNovel_003_009']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/30_11_2020/YMaze_LNovel/YMaze_LNovel_003_009/YMaze_LNovel_003_009.h5']
# time 1817.34 sec. Wrote 23026 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 23026 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 17.66 sec.
# Registered 2000/23026 in 124.98s
# Registered 4000/23026 in 237.71s
# Registered 6000/23026 in 360.13s
# Registered 8000/23026 in 481.68s
# Registered 10000/23026 in 592.75s
# Registered 12000/23026 in 705.64s
# Registered 14000/23026 in 828.73s
# Registered 16000/23026 in 955.23s
# Registered 18000/23026 in 1076.19s
# Registered 20000/23026 in 1203.33s
# Registered 22000/23026 in 1307.14s
# Registered second channel in 733.45 sec.
# ----------- Total 2122.59 sec
# Registration metrics, 102.34 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2060,416,694], 317.52 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.72, threshold 17.17
# 0 ROIs, score=385.69
# 1000 ROIs, score=56.22
# 2000 ROIs, score=18.71
# Found 2081 ROIs, 91.23 sec
# After removing overlaps, 1895 ROIs remain
# Masks made in 66.20 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 545.41 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1895 ROIs in 23026 frames, 281.14 sec.
# Extracted fluorescence from 1895 ROIs in 23026 frames, 284.51 sec.
# added enhanced mean image
# ----------- Total 586.17 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.88 sec.
# Plane 0 processed in 3364.05 sec (can open in GUI).
# total = 5183.07 sec.
# TOTAL RUNTIME 5183.07 sec
# {'date': '01_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 31511
# ['/mnt/BigDisk/2P_scratch/4467332.2/01_12_2020/YMaze_LNovel/YMaze_LNovel_001_004']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/01_12_2020/YMaze_LNovel/YMaze_LNovel_001_004/YMaze_LNovel_001_004.h5']
# time 2849.39 sec. Wrote 31511 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 31511 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 20.51 sec.
# Registered 2000/31511 in 111.36s
# Registered 4000/31511 in 220.38s
# Registered 6000/31511 in 335.68s
# Registered 8000/31511 in 451.61s
# Registered 10000/31511 in 562.45s
# Registered 12000/31511 in 672.26s
# Registered 14000/31511 in 783.64s
# Registered 16000/31511 in 896.78s
# Registered 18000/31511 in 1008.47s
# Registered 20000/31511 in 1126.70s
# Registered 22000/31511 in 1244.78s
# Registered 24000/31511 in 1365.46s
# Registered 26000/31511 in 1480.60s
# Registered 28000/31511 in 1591.97s
# Registered 30000/31511 in 1705.01s
# Registered 31511/31511 in 1789.19s
# Registered second channel in 808.88 sec.
# ----------- Total 2627.62 sec
# Registration metrics, 89.50 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2811,416,694], 446.29 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.34, threshold 23.42
# 0 ROIs, score=466.83
# 1000 ROIs, score=64.67
# Found 1966 ROIs, 106.60 sec
# After removing overlaps, 1814 ROIs remain
# Masks made in 56.62 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 673.80 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1814 ROIs in 31511 frames, 506.08 sec.
# Extracted fluorescence from 1814 ROIs in 31511 frames, 578.86 sec.
# added enhanced mean image
# ----------- Total 1100.64 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.64 sec.
# Plane 0 processed in 4496.60 sec (can open in GUI).
# total = 7351.99 sec.
# TOTAL RUNTIME 7351.99 sec
# {'date': '02_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 4}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 31538
# ['/mnt/BigDisk/2P_scratch/4467332.2/02_12_2020/YMaze_LNovel/YMaze_LNovel_001_004']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/02_12_2020/YMaze_LNovel/YMaze_LNovel_001_004/YMaze_LNovel_001_004.h5']
# time 1748.25 sec. Wrote 31538 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 31538 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 16.89 sec.
# Registered 2000/31538 in 94.84s
# Registered 4000/31538 in 190.27s
# Registered 6000/31538 in 284.70s
# Registered 8000/31538 in 380.76s
# Registered 10000/31538 in 476.86s
# Registered 12000/31538 in 569.16s
# Registered 14000/31538 in 663.69s
# Registered 16000/31538 in 758.49s
# Registered 18000/31538 in 854.41s
# Registered 20000/31538 in 948.61s
# Registered 22000/31538 in 1042.63s
# Registered 24000/31538 in 1135.07s
# Registered 26000/31538 in 1233.36s
# Registered 28000/31538 in 1329.02s
# Registered 30000/31538 in 1425.70s
# Registered 31538/31538 in 1499.39s
# Registered second channel in 478.48 sec.
# ----------- Total 2003.61 sec
# Registration metrics, 49.92 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2815,416,694], 284.21 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.35, threshold 23.46
# 0 ROIs, score=468.25
# 1000 ROIs, score=68.73
# 2000 ROIs, score=27.91
# Found 2163 ROIs, 104.00 sec
# After removing overlaps, 1970 ROIs remain
# Masks made in 62.37 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 521.83 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1970 ROIs in 31538 frames, 519.35 sec.
# Extracted fluorescence from 1970 ROIs in 31538 frames, 397.68 sec.
# added enhanced mean image
# ----------- Total 934.74 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.84 sec.
# Plane 0 processed in 3515.30 sec (can open in GUI).
# total = 5266.21 sec.
# TOTAL RUNTIME 5266.21 sec
# {'date': '03_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 33460
# ['/mnt/BigDisk/2P_scratch/4467332.2/03_12_2020/YMaze_LNovel/YMaze_LNovel_001_003']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/03_12_2020/YMaze_LNovel/YMaze_LNovel_001_003/YMaze_LNovel_001_003.h5']
# time 1938.37 sec. Wrote 33460 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 33460 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 16.89 sec.
# Registered 2000/33460 in 95.62s
# Registered 4000/33460 in 188.80s
# Registered 6000/33460 in 284.31s
# Registered 8000/33460 in 378.53s
# Registered 10000/33460 in 471.72s
# Registered 12000/33460 in 565.11s
# Registered 14000/33460 in 657.75s
# Registered 16000/33460 in 751.15s
# Registered 18000/33460 in 845.02s
# Registered 20000/33460 in 938.20s
# Registered 22000/33460 in 1032.73s
# Registered 24000/33460 in 1125.96s
# Registered 26000/33460 in 1219.50s
# Registered 28000/33460 in 1308.99s
# Registered 30000/33460 in 1397.84s
# Registered 32000/33460 in 1485.14s
# Registered second channel in 568.24 sec.
# ----------- Total 2145.50 sec
# Registration metrics, 48.62 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2950,416,694], 302.23 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.46, threshold 24.58
# 0 ROIs, score=496.38
# 1000 ROIs, score=61.66
# Found 1789 ROIs, 102.64 sec
# After removing overlaps, 1669 ROIs remain
# Masks made in 46.79 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 505.93 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1669 ROIs in 33460 frames, 422.91 sec.
# Extracted fluorescence from 1669 ROIs in 33460 frames, 512.27 sec.
# added enhanced mean image
# ----------- Total 950.11 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.17 sec.
# Plane 0 processed in 3654.40 sec (can open in GUI).
# total = 5593.74 sec.
# TOTAL RUNTIME 5593.74 sec
# {'date': '04_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 35784
# ['/mnt/BigDisk/2P_scratch/4467332.2/04_12_2020/YMaze_LNovel/YMaze_LNovel_001_003']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/04_12_2020/YMaze_LNovel/YMaze_LNovel_001_003/YMaze_LNovel_001_003.h5']
# time 1835.09 sec. Wrote 35784 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 35784 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 17.29 sec.
# Registered 2000/35784 in 88.31s
# Registered 4000/35784 in 171.94s
# Registered 6000/35784 in 263.69s
# Registered 8000/35784 in 360.25s
# Registered 10000/35784 in 454.91s
# Registered 12000/35784 in 553.27s
# Registered 14000/35784 in 649.61s
# Registered 16000/35784 in 746.46s
# Registered 18000/35784 in 838.87s
# Registered 20000/35784 in 936.41s
# Registered 22000/35784 in 1033.96s
# Registered 24000/35784 in 1132.11s
# Registered 26000/35784 in 1227.97s
# Registered 28000/35784 in 1325.69s
# Registered 30000/35784 in 1421.78s
# Registered 32000/35784 in 1516.39s
# Registered 34000/35784 in 1610.00s
# Registered 35784/35784 in 1697.56s
# Registered second channel in 620.42 sec.
# ----------- Total 2344.11 sec
# Registration metrics, 54.54 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3179,416,694], 318.26 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.65, threshold 26.49
# 0 ROIs, score=575.49
# 1000 ROIs, score=68.60
# Found 1897 ROIs, 111.14 sec
# After removing overlaps, 1767 ROIs remain
# Masks made in 53.47 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 542.88 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1767 ROIs in 35784 frames, 400.19 sec.
# Extracted fluorescence from 1767 ROIs in 35784 frames, 508.40 sec.
# added enhanced mean image
# ----------- Total 924.29 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.03 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.91 sec.
# Plane 0 processed in 3870.92 sec (can open in GUI).
# total = 5713.14 sec.
# TOTAL RUNTIME 5713.14 sec
# {'date': '06_12_2020', 'scene': 'YMaze_RewardReversal', 'session': 2, 'scan': 2}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 37538
# ['/mnt/BigDisk/2P_scratch/4467332.2/06_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_002_002']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/06_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_002_002/YMaze_RewardReversal_002_002.h5']
# time 1313.81 sec. Wrote 37538 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 37538 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 20.34 sec.
# Registered 2000/37538 in 90.26s
# Registered 4000/37538 in 180.28s
# Registered 6000/37538 in 271.70s
# Registered 8000/37538 in 361.77s
# Registered 10000/37538 in 454.09s
# Registered 12000/37538 in 546.01s
# Registered 14000/37538 in 636.46s
# Registered 16000/37538 in 728.26s
# Registered 18000/37538 in 821.72s
# Registered 20000/37538 in 911.37s
# Registered 22000/37538 in 1003.70s
# Registered 24000/37538 in 1100.65s
# Registered 26000/37538 in 1197.51s
# Registered 28000/37538 in 1287.45s
# Registered 30000/37538 in 1375.05s
# Registered 32000/37538 in 1463.14s
# Registered 34000/37538 in 1549.70s
# Registered 36000/37538 in 1643.97s
# Registered 37538/37538 in 1717.60s
# Registered second channel in 510.49 sec.
# ----------- Total 2257.99 sec
# Registration metrics, 43.03 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3360,416,694], 282.27 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.80, threshold 28.00
# 0 ROIs, score=613.74
# 1000 ROIs, score=86.41
# 2000 ROIs, score=32.51
# Found 2129 ROIs, 117.52 sec
# After removing overlaps, 1964 ROIs remain
# Masks made in 63.87 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 539.63 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1964 ROIs in 37538 frames, 375.21 sec.
# Extracted fluorescence from 1964 ROIs in 37538 frames, 383.57 sec.
# added enhanced mean image
# ----------- Total 775.08 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.47 sec.
# Plane 0 processed in 3621.52 sec (can open in GUI).
# total = 4937.82 sec.
# TOTAL RUNTIME 4937.82 sec

# %%
_file_list = ({'date': '06_12_2020', 'scene':'YMaze_LNovel','session':1,'scan':3}, 
             {'date':'06_12_2020','scene':'YMaze_RewardReversal', 'session':1,'scan':6},)

_h5list,_frs = check_and_make_h5s(_file_list)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"05_12_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':1.,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '06_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 3}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 10151
# {'date': '06_12_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 6}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 24407
# ['/mnt/BigDisk/2P_scratch/4467332.2/06_12_2020/YMaze_LNovel/YMaze_LNovel_001_003', '/mnt/BigDisk/2P_scratch/4467332.2/06_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_006']
# {}
# h5
# ** Found 2 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/06_12_2020/YMaze_LNovel/YMaze_LNovel_001_003/YMaze_LNovel_001_003.h5', '/mnt/BigDisk/2P_scratch/4467332.2/06_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_006/YMaze_RewardReversal_001_006.h5']
# time 1393.80 sec. Wrote 34558 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 34558 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 20.45 sec.
# Registered 2000/34558 in 92.85s
# Registered 4000/34558 in 183.50s
# Registered 6000/34558 in 276.92s
# Registered 8000/34558 in 368.69s
# Registered 10000/34558 in 459.30s
# Registered 12000/34558 in 551.23s
# Registered 14000/34558 in 649.00s
# Registered 16000/34558 in 749.12s
# Registered 18000/34558 in 841.46s
# Registered 20000/34558 in 931.68s
# Registered 22000/34558 in 1021.46s
# Registered 24000/34558 in 1113.38s
# Registered 26000/34558 in 1211.55s
# Registered 28000/34558 in 1309.28s
# Registered 30000/34558 in 1393.49s
# Registered 32000/34558 in 1477.43s
# Registered 34000/34558 in 1561.55s
# Registered second channel in 501.03 sec.
# ----------- Total 2116.91 sec
# Registration metrics, 46.88 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3093,416,694], 285.17 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.58, threshold 25.78
# 0 ROIs, score=590.08
# 1000 ROIs, score=74.42
# 2000 ROIs, score=25.99
# Found 2007 ROIs, 114.71 sec
# After removing overlaps, 1866 ROIs remain
# Masks made in 57.00 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 523.42 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1866 ROIs in 34558 frames, 376.28 sec.
# Extracted fluorescence from 1866 ROIs in 34558 frames, 378.18 sec.
# added enhanced mean image
# ----------- Total 770.76 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.22 sec.
# Plane 0 processed in 3463.29 sec (can open in GUI).
# total = 4860.22 sec.
# TOTAL RUNTIME 4860.22 sec

# %%
_file_list = ({'date': '07_12_2020', 'scene':'YMaze_RewardReversal','session':1,'scan':2}, 
             {'date':'07_12_2020','scene':'YMaze_LNovel', 'session':1,'scan':6})

_h5list,_frs = check_and_make_h5s(_file_list)
ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                               'save_path0': os.path.join(write_folder,mouse,"07_12_2020","combined"),
                                'fast_disk':[],
                                'move_bin':True,
                                'two_step_registration':True,
                                'maxregshiftNR':10,
                                'nchannels':2,
                                'tau':.7,
                                'functional_chan':1,
                                'fs':_frs[0],
                                'roidetect':True,
                                'input_format':"h5",
                                'h5py_key':'data',
                                'nchannels':2,
                                'threshold_scaling':1.,
                                'chan2_thresh':.01})
ops=s2p.run_s2p(ops=ops)
for h5 in _h5list:
    # !rm {h5}/*.h5
# Out:
# {'date': '07_12_2020', 'scene': 'YMaze_RewardReversal', 'session': 1, 'scan': 2}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 10643
# {'date': '07_12_2020', 'scene': 'YMaze_LNovel', 'session': 1, 'scan': 6}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 26609
# ['/mnt/BigDisk/2P_scratch/4467332.2/07_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_002', '/mnt/BigDisk/2P_scratch/4467332.2/07_12_2020/YMaze_LNovel/YMaze_LNovel_001_006']
# {}
# h5
# ** Found 2 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.2/07_12_2020/YMaze_RewardReversal/YMaze_RewardReversal_001_002/YMaze_RewardReversal_001_002.h5', '/mnt/BigDisk/2P_scratch/4467332.2/07_12_2020/YMaze_LNovel/YMaze_LNovel_001_006/YMaze_LNovel_001_006.h5']
# time 1476.68 sec. Wrote 37252 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 37252 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 22.72 sec.
# Registered 2000/37252 in 99.51s
# Registered 4000/37252 in 196.82s
# Registered 6000/37252 in 286.48s
# Registered 8000/37252 in 380.33s
# Registered 10000/37252 in 467.95s
# Registered 12000/37252 in 565.54s
# Registered 14000/37252 in 663.54s
# Registered 16000/37252 in 753.02s
# Registered 18000/37252 in 838.61s
# Registered 20000/37252 in 923.31s
# Registered 22000/37252 in 1011.24s
# Registered 24000/37252 in 1097.45s
# Registered 26000/37252 in 1181.54s
# Registered 28000/37252 in 1269.97s
# Registered 30000/37252 in 1355.61s
# Registered 32000/37252 in 1441.05s
# Registered 34000/37252 in 1528.32s
# Registered 36000/37252 in 1615.80s
# Registered second channel in 545.59 sec.
# ----------- Total 2249.77 sec
# Registration metrics, 52.19 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3316,416,694], 306.22 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.76, threshold 27.63
# 0 ROIs, score=556.89
# 1000 ROIs, score=84.41
# 2000 ROIs, score=32.05
# Found 2149 ROIs, 129.69 sec
# After removing overlaps, 1973 ROIs remain
# Masks made in 68.07 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 586.14 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1973 ROIs in 37252 frames, 405.39 sec.
# Extracted fluorescence from 1973 ROIs in 37252 frames, 410.13 sec.
# added enhanced mean image
# ----------- Total 830.56 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.15 sec.
# Plane 0 processed in 3724.19 sec (can open in GUI).
# total = 5204.97 sec.
# TOTAL RUNTIME 5204.97 sec
