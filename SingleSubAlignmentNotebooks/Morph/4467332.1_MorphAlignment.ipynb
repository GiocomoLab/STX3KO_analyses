# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
write_folder = os.path.join('/mnt','BigDisk','2P_scratch')


mouse = '4467332.1'

file_list = ({'date': '11_12_2020', 'scene':'TwoTower_foraging','session':3,'scan':4},
             {'date': '14_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':1},
             {'date': '16_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':2},
             {'date': '17_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':2},
             {'date': '18_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':2},
             {'date': '19_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':4},
             )

# %%
def check_and_make_h5s(file_list,runh5=True):
    h5list, framerates = [], []
    for f in file_list:
        print(f)
        scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
        try:
            source_folder  = os.path.join('/media','mplitt','Backup Plus5','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        except:
            source_folder  = os.path.join('/media','mplitt','Backup Plus3')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        
        file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
        h5path = os.path.join(file_stem,scan_str+".h5")
        if not os.path.exists(h5path) and runh5:
            _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)

        h5list.append(file_stem)
        framerates.append(info['frame_rate'])
    print(h5list)
    return h5list, framerates

# %%
for f in file_list:
    _h5list,_frs = check_and_make_h5s([f,],runh5=True)
    ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                                   'save_path0': _h5list[0],
                                    'fast_disk':[],
                                    'move_bin':True,
                                    'two_step_registration':True,
                                    'maxregshiftNR':10,
                                    'nchannels':2,
                                    'tau':.7,
                                    'functional_chan':1,
                                    'fs':_frs[0],
                                    'roidetect':True,
                                    'input_format':"h5",
                                    'h5py_key':'data',
                                    'nchannels':2,
                                    'threshold_scaling':1.1,
                                    'chan2_thresh':.01})
    ops=s2p.run_s2p(ops=ops)
    # !rm {_h5list[0]}/*.h5
# Out:
# {'date': '11_12_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 4}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 22232
# ['/mnt/BigDisk/2P_scratch/4467332.1/11_12_2020/TwoTower_foraging/TwoTower_foraging_003_004']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/11_12_2020/TwoTower_foraging/TwoTower_foraging_003_004/TwoTower_foraging_003_004.h5']
# time 1043.40 sec. Wrote 22232 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 22232 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 22.53 sec.
# Registered 2000/22232 in 134.09s
# Registered 4000/22232 in 217.81s
# Registered 6000/22232 in 305.31s
# Registered 8000/22232 in 395.72s
# Registered 10000/22232 in 482.91s
# Registered 12000/22232 in 571.28s
# Registered 14000/22232 in 659.94s
# Registered 16000/22232 in 746.89s
# Registered 18000/22232 in 841.08s
# Registered 20000/22232 in 940.13s
# Registered 22000/22232 in 1037.84s
# Registered second channel in 636.08 sec.
# ----------- Total 1720.45 sec
# Registration metrics, 78.38 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1980,504,774], 248.24 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.65, threshold 18.15
# 0 ROIs, score=420.00
# 1000 ROIs, score=52.79
# 2000 ROIs, score=19.73
# Found 2075 ROIs, 90.66 sec
# After removing overlaps, 1906 ROIs remain
# Masks made in 47.00 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 440.09 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1906 ROIs in 22232 frames, 257.14 sec.
# Extracted fluorescence from 1906 ROIs in 22232 frames, 253.81 sec.
# added enhanced mean image
# ----------- Total 526.04 sec.
# ----------- CLASSIFICATION
# ['skew', 'compact', 'npix_norm']
# ----------- Total 0.17 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.36 sec.
# Plane 0 processed in 2768.54 sec (can open in GUI).
# total = 3813.06 sec.
# TOTAL RUNTIME 3813.06 sec
# {'date': '14_12_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 1}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 18393
# ['/mnt/BigDisk/2P_scratch/4467332.1/14_12_2020/TwoTower_foraging/TwoTower_foraging_002_001']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467332.1/14_12_2020/TwoTower_foraging/TwoTower_foraging_002_001/TwoTower_foraging_002_001.h5']
# time 861.60 sec. Wrote 18393 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 18393 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 16.80 sec.
# Registered 2000/18393 in 84.85s
