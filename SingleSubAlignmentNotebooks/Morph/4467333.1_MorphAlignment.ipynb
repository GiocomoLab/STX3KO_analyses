# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
source_folder  = os.path.join('/media','mplitt','Backup Plus1','2P_Data')
write_folder = os.path.join('/home','mplitt','2P_scratch')


mouse = '4467333.1'

file_list = ({'date': '11_12_2020', 'scene':'TwoTower_foraging','session':3,'scan':4},
             {'date': '14_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':1},
             {'date': '16_12_2020', 'scene':'TwoTower_foraging','session':3,'scan':1},
             {'date': '17_12_2020', 'scene':'TwoTower_foraging','session':3,'scan':4},
             {'date': '18_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':2},
             {'date': '19_12_2020', 'scene':'TwoTower_foraging','session':3,'scan':6},
             )

# %%
def check_and_make_h5s(file_list,runh5=True):
    h5list, framerates = [], []
    for f in file_list:
        print(f)
        scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
        try:
            source_folder  = os.path.join('/media','mplitt','Backup Plus3')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        except:
            source_folder  = os.path.join('/media','mplitt','Backup Plus5','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        
        file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
        h5path = os.path.join(file_stem,scan_str+".h5")
        if not os.path.exists(h5path) and runh5:
            _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)

        h5list.append(file_stem)
        framerates.append(info['frame_rate'])
    print(h5list)
    return h5list, framerates

# %%
for f in file_list:
    _h5list,_frs = check_and_make_h5s([f,], runh5=True)
    ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                                   'save_path0': _h5list[0],
                                    'fast_disk':[],
                                    'move_bin':True,
                                    'two_step_registration':True,
                                    'maxregshiftNR':10,
                                    'nchannels':2,
                                    'tau':.7,
                                    'functional_chan':1,
                                    'fs':_frs[0],
                                    'roidetect':True,
                                    'input_format':"h5",
                                    'h5py_key':'data',
                                    'nchannels':2,
                                    'threshold_scaling':1.,
                                    'chan2_thresh':.01})
    ops=s2p.run_s2p(ops=ops)
    # !rm {_h5list[0]}/*.h5
# Out:
# {'date': '11_12_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 4}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 30740
# ['/home/mplitt/2P_scratch/4467333.1/11_12_2020/TwoTower_foraging/TwoTower_foraging_003_004']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467333.1/11_12_2020/TwoTower_foraging/TwoTower_foraging_003_004/TwoTower_foraging_003_004.h5']
# time 261.05 sec. Wrote 30740 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 30740 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 21.37 sec.
# Registered 2000/30740 in 82.85s
# Registered 4000/30740 in 166.33s
# Registered 6000/30740 in 249.20s
# Registered 8000/30740 in 330.29s
# Registered 10000/30740 in 411.51s
# Registered 12000/30740 in 488.49s
# Registered 14000/30740 in 566.16s
# Registered 16000/30740 in 643.69s
# Registered 18000/30740 in 731.01s
# Registered 20000/30740 in 810.44s
# Registered 22000/30740 in 891.59s
# Registered 24000/30740 in 972.73s
# Registered 26000/30740 in 1053.51s
# Registered 28000/30740 in 1135.86s
# Registered 30000/30740 in 1216.21s
# Registered second channel in 218.04 sec.
# ----------- Total 1490.89 sec
# Registration metrics, 39.15 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2745,502,754], 78.05 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.29, threshold 22.88
# 0 ROIs, score=620.65
# 1000 ROIs, score=69.75
# Found 1950 ROIs, 114.70 sec
# After removing overlaps, 1760 ROIs remain
# Masks made in 53.45 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 306.44 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1760 ROIs in 30740 frames, 134.66 sec.
# Extracted fluorescence from 1760 ROIs in 30740 frames, 121.70 sec.
# added enhanced mean image
# ----------- Total 270.35 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.08 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.96 sec.
# Plane 0 processed in 2111.01 sec (can open in GUI).
# total = 2373.06 sec.
# TOTAL RUNTIME 2373.07 sec
# {'date': '14_12_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 1}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 19516
# ['/home/mplitt/2P_scratch/4467333.1/14_12_2020/TwoTower_foraging/TwoTower_foraging_002_001']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467333.1/14_12_2020/TwoTower_foraging/TwoTower_foraging_002_001/TwoTower_foraging_002_001.h5']
# time 169.48 sec. Wrote 19516 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 19516 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 17.83 sec.
# Registered 2000/19516 in 73.30s
# Registered 4000/19516 in 146.43s
# Registered 6000/19516 in 220.20s
# Registered 8000/19516 in 293.72s
# Registered 10000/19516 in 366.09s
# Registered 12000/19516 in 440.21s
# Registered 14000/19516 in 511.84s
# Registered 16000/19516 in 582.85s
# Registered 18000/19516 in 653.94s
# Registered 19516/19516 in 707.74s
# Registered second channel in 124.02 sec.
# ----------- Total 855.39 sec
# Registration metrics, 33.71 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1755,498,776], 47.63 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.46, threshold 14.62
# 0 ROIs, score=536.61
# 1000 ROIs, score=57.33
# 2000 ROIs, score=21.08
# Found 2389 ROIs, 87.54 sec
# After removing overlaps, 2003 ROIs remain
# Masks made in 74.14 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 292.00 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2003 ROIs in 19516 frames, 81.34 sec.
# Extracted fluorescence from 2003 ROIs in 19516 frames, 78.92 sec.
# added enhanced mean image
# ----------- Total 174.04 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.04 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.33 sec.
# Plane 0 processed in 1358.46 sec (can open in GUI).
# total = 1528.93 sec.
# TOTAL RUNTIME 1528.93 sec
# {'date': '16_12_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 1}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 19828
# ['/home/mplitt/2P_scratch/4467333.1/16_12_2020/TwoTower_foraging/TwoTower_foraging_003_001']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467333.1/16_12_2020/TwoTower_foraging/TwoTower_foraging_003_001/TwoTower_foraging_003_001.h5']
# time 176.57 sec. Wrote 19828 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 19828 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 19.80 sec.
# Registered 2000/19828 in 76.39s
# Registered 4000/19828 in 154.40s
# Registered 6000/19828 in 231.31s
# Registered 8000/19828 in 307.51s
# Registered 10000/19828 in 385.31s
# Registered 12000/19828 in 462.85s
# Registered 14000/19828 in 541.84s
# Registered 16000/19828 in 623.78s
# Registered 18000/19828 in 708.88s
# Registered 19828/19828 in 784.74s
# Registered second channel in 150.20 sec.
# ----------- Total 960.96 sec
# Registration metrics, 39.65 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1755,504,774], 54.83 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.46, threshold 14.62
# 0 ROIs, score=509.43
# 1000 ROIs, score=50.36
# 2000 ROIs, score=14.70
# Found 2009 ROIs, 109.05 sec
# After removing overlaps, 1732 ROIs remain
# Masks made in 57.57 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 287.25 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1732 ROIs in 19828 frames, 95.49 sec.
# Extracted fluorescence from 1732 ROIs in 19828 frames, 102.20 sec.
# added enhanced mean image
# ----------- Total 212.56 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.12 sec.
# Plane 0 processed in 1503.69 sec (can open in GUI).
# total = 1681.33 sec.
# TOTAL RUNTIME 1681.33 sec
# {'date': '17_12_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 4}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 27140
# ['/home/mplitt/2P_scratch/4467333.1/17_12_2020/TwoTower_foraging/TwoTower_foraging_003_004']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467333.1/17_12_2020/TwoTower_foraging/TwoTower_foraging_003_004/TwoTower_foraging_003_004.h5']
# time 225.20 sec. Wrote 27140 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 27140 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 21.60 sec.
# Registered 2000/27140 in 77.71s
# Registered 4000/27140 in 152.11s
# Registered 6000/27140 in 229.33s
# Registered 8000/27140 in 305.16s
# Registered 10000/27140 in 380.10s
# Registered 12000/27140 in 454.34s
# Registered 14000/27140 in 527.53s
# Registered 16000/27140 in 601.45s
# Registered 18000/27140 in 674.41s
# Registered 20000/27140 in 748.13s
# Registered 22000/27140 in 819.16s
# Registered 24000/27140 in 889.30s
# Registered 26000/27140 in 959.31s
# Registered second channel in 183.49 sec.
# ----------- Total 1210.71 sec
# Registration metrics, 34.57 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2430,502,774], 70.98 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.02, threshold 20.25
# 0 ROIs, score=596.24
# 1000 ROIs, score=56.18
# Found 1842 ROIs, 114.08 sec
# After removing overlaps, 1618 ROIs remain
# Masks made in 53.27 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 299.27 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1618 ROIs in 27140 frames, 119.18 sec.
# Extracted fluorescence from 1618 ROIs in 27140 frames, 118.03 sec.
# added enhanced mean image
# ----------- Total 251.62 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.08 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.89 sec.
# Plane 0 processed in 1800.36 sec (can open in GUI).
# total = 2026.61 sec.
# TOTAL RUNTIME 2026.61 sec
# {'date': '18_12_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 2}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 29990
# ['/home/mplitt/2P_scratch/4467333.1/18_12_2020/TwoTower_foraging/TwoTower_foraging_002_002']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467333.1/18_12_2020/TwoTower_foraging/TwoTower_foraging_002_002/TwoTower_foraging_002_002.h5']
# time 242.45 sec. Wrote 29990 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 29990 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 17.69 sec.
# Registered 2000/29990 in 71.21s
# Registered 4000/29990 in 142.09s
# Registered 6000/29990 in 212.40s
# Registered 8000/29990 in 283.26s
# Registered 10000/29990 in 353.62s
# Registered 12000/29990 in 424.24s
# Registered 14000/29990 in 497.17s
# Registered 16000/29990 in 568.69s
# Registered 18000/29990 in 639.30s
# Registered 20000/29990 in 709.96s
# Registered 22000/29990 in 780.55s
# Registered 24000/29990 in 851.03s
# Registered 26000/29990 in 921.42s
# Registered 28000/29990 in 991.75s
# Registered 29990/29990 in 1062.05s
# Registered second channel in 189.64 sec.
# ----------- Total 1275.27 sec
# Registration metrics, 33.00 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2655,502,768], 71.15 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.21, threshold 22.12
# 0 ROIs, score=633.00
# 1000 ROIs, score=64.04
# Found 1989 ROIs, 140.44 sec
# After removing overlaps, 1711 ROIs remain
# Masks made in 56.95 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 332.97 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1711 ROIs in 29990 frames, 115.28 sec.
# Extracted fluorescence from 1711 ROIs in 29990 frames, 112.03 sec.
# added enhanced mean image
# ----------- Total 241.18 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.07 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.85 sec.
# Plane 0 processed in 1886.41 sec (can open in GUI).
# total = 2129.88 sec.
# TOTAL RUNTIME 2129.88 sec
# {'date': '19_12_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 6}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 20000
# 20000 21000
# 21000 22000
# 22000 23000
# 23000 24000
# 24000 25000
# 25000 26000
# 26000 27000
# 27000 28000
# 28000 29000
# 29000 30000
# 30000 31000
# 31000 32000
# 32000 33000
# 33000 34000
# 34000 35000
# 35000 36000
# 36000 37000
# 37000 38000
# 38000 38845
# ['/home/mplitt/2P_scratch/4467333.1/19_12_2020/TwoTower_foraging/TwoTower_foraging_003_006']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/home/mplitt/2P_scratch/4467333.1/19_12_2020/TwoTower_foraging/TwoTower_foraging_003_006/TwoTower_foraging_003_006.h5']
# time 347.09 sec. Wrote 38845 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 38845 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 22.82 sec.
# Registered 2000/38845 in 84.99s
# Registered 4000/38845 in 171.00s
# Registered 6000/38845 in 255.35s
# Registered 8000/38845 in 340.05s
# Registered 10000/38845 in 424.87s
# Registered 12000/38845 in 509.85s
# Registered 14000/38845 in 594.57s
# Registered 16000/38845 in 679.92s
# Registered 18000/38845 in 763.52s
# Registered 20000/38845 in 845.16s
# Registered 22000/38845 in 926.72s
# Registered 24000/38845 in 1009.01s
# Registered 26000/38845 in 1092.22s
# Registered 28000/38845 in 1173.18s
# Registered 30000/38845 in 1251.54s
# Registered 32000/38845 in 1328.18s
# Registered 34000/38845 in 1402.03s
# Registered 36000/38845 in 1477.07s
# Registered 38000/38845 in 1552.18s
# Registered second channel in 264.81 sec.
# ----------- Total 1879.39 sec
# Registration metrics, 33.85 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3465,502,770], 104.93 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 2.89, threshold 28.88
# 0 ROIs, score=727.40
# 1000 ROIs, score=78.74
# Found 1933 ROIs, 183.54 sec
# After removing overlaps, 1709 ROIs remain
# Masks made in 61.42 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 419.50 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 1709 ROIs in 38845 frames, 178.53 sec.
# Extracted fluorescence from 1709 ROIs in 38845 frames, 169.92 sec.
# added enhanced mean image
# ----------- Total 363.21 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# ----------- Total 0.08 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 4.42 sec.
# Plane 0 processed in 2701.92 sec (can open in GUI).
# total = 3050.13 sec.
# TOTAL RUNTIME 3050.13 sec
