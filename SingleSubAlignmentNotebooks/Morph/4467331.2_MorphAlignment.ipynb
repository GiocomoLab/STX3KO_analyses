# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
write_folder = os.path.join('/mnt','BigDisk','2P_scratch')


mouse = '4467331.2'

file_list = ({'date': '10_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':2},
             {'date': '14_12_2020', 'scene':'TwoTower_foraging','session':1,'scan':3},
             {'date': '15_12_2020', 'scene':'TwoTower_foraging','session':3,'scan':5},
             {'date': '16_12_2020', 'scene':'TwoTower_foraging','session':4,'scan':4},
             {'date': '17_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':5},
             {'date': '18_12_2020', 'scene':'TwoTower_foraging','session':2,'scan':3},
             {'date': '19_12_2020', 'scene':'TwoTower_foraging','session':3,'scan':6},
             {'date': '19_12_2020', 'scene':'TwoTower_foraging','session':4,'scan':3},
             )

# %%
def check_and_make_h5s(file_list,runh5=True):
    h5list, framerates = [], []
    for f in file_list:
        print(f)
        scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
        try:
            source_folder  = os.path.join('/media','mplitt','Backup Plus5','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        except:
            source_folder  = os.path.join('/media','mplitt','Backup Plus3')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        
        file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
        h5path = os.path.join(file_stem,scan_str+".h5")
        if not os.path.exists(h5path) and runh5:
            _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)

        h5list.append(file_stem)
        framerates.append(info['frame_rate'])
    print(h5list)
    return h5list, framerates

# %%
for f in file_list:
    _h5list,_frs = check_and_make_h5s([f,],runh5=True)
    ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                                   'save_path0': _h5list[0],
                                    'fast_disk':[],
                                    'move_bin':True,
                                    'two_step_registration':True,
                                    'maxregshiftNR':10,
                                    'nchannels':2,
                                    'tau':.7,
                                    'functional_chan':1,
                                    'fs':_frs[0],
                                    'roidetect':True,
                                    'input_format':"h5",
                                    'h5py_key':'data',
                                    'nchannels':2,
                                    'threshold_scaling':.9,
                                    'chan2_thresh':.01})
    ops=s2p.run_s2p(ops=ops)
    # !rm {_h5list[0]}/*.h5
# Out:
# {'date': '10_12_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 2}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 17389
# ['/mnt/BigDisk/2P_scratch/4467331.2/10_12_2020/TwoTower_foraging/TwoTower_foraging_002_002']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467331.2/10_12_2020/TwoTower_foraging/TwoTower_foraging_002_002/TwoTower_foraging_002_002.h5']
# time 607.19 sec. Wrote 17389 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 17389 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 16.47 sec.
# Registered 2000/17389 in 80.16s
# Registered 4000/17389 in 159.52s
# Registered 6000/17389 in 246.94s
# Registered 8000/17389 in 335.21s
# Registered 10000/17389 in 422.52s
# Registered 12000/17389 in 511.81s
# Registered 14000/17389 in 599.10s
# Registered 16000/17389 in 685.08s
# Registered second channel in 298.64 sec.
# ----------- Total 1071.00 sec
# Registration metrics, 106.83 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1530,498,776], 241.62 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.27, threshold 11.47
# 0 ROIs, score=312.73
# 1000 ROIs, score=50.74
# 2000 ROIs, score=20.96
# Found 2652 ROIs, 79.07 sec
# After removing overlaps, 2240 ROIs remain
# Masks made in 98.19 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 524.99 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2240 ROIs in 17389 frames, 281.28 sec.
# Extracted fluorescence from 2240 ROIs in 17389 frames, 273.12 sec.
# added enhanced mean image
# ----------- Total 568.55 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- Total 0.08 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.23 sec.
# Plane 0 processed in 2274.79 sec (can open in GUI).
# total = 2882.97 sec.
# TOTAL RUNTIME 2882.97 sec
# {'date': '14_12_2020', 'scene': 'TwoTower_foraging', 'session': 1, 'scan': 3}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
# 6000 7000
# 7000 8000
# 8000 9000
# 9000 10000
# 10000 11000
# 11000 12000
# 12000 13000
# 13000 14000
# 14000 15000
# 15000 16000
# 16000 17000
# 17000 18000
# 18000 19000
# 19000 19744
# ['/mnt/BigDisk/2P_scratch/4467331.2/14_12_2020/TwoTower_foraging/TwoTower_foraging_001_003']
# {}
# h5
# ** Found 1 h5 files - converting to binary **
# NOTE: using a list of h5 files:
# ['/mnt/BigDisk/2P_scratch/4467331.2/14_12_2020/TwoTower_foraging/TwoTower_foraging_001_003/TwoTower_foraging_001_003.h5']
# time 1043.35 sec. Wrote 19744 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# ----------- REGISTRATION
# registering 19744 frames
# NOTE: estimated bidiphase offset from data: 0 pixels
# Reference frame, 17.04 sec.
# Registered 2000/19744 in 94.61s
# Registered 4000/19744 in 185.00s
# Registered 6000/19744 in 274.23s
# Registered 8000/19744 in 355.07s
# Registered 10000/19744 in 447.57s
# Registered 12000/19744 in 540.74s
# Registered 14000/19744 in 633.64s
# Registered 16000/19744 in 724.69s
# Registered 18000/19744 in 818.27s
# Registered 19744/19744 in 896.16s
# Registered second channel in 405.68 sec.
# ----------- Total 1329.54 sec
# Registration metrics, 54.41 sec.
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1755,502,764], 187.68 sec.
# NOTE: estimated spatial scale ~12 pixels, time epochs 1.46, threshold 13.16
# 0 ROIs, score=334.10
# 1000 ROIs, score=41.40
# 2000 ROIs, score=16.78
# Found 2310 ROIs, 109.30 sec
# After removing overlaps, 2015 ROIs remain
# Masks made in 57.76 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 420.87 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2015 ROIs in 19744 frames, 313.86 sec.
# Extracted fluorescence from 2015 ROIs in 19744 frames, 336.15 sec.
# added enhanced mean image
# ----------- Total 668.93 sec.
# ----------- CLASSIFICATION
# ['compact', 'npix_norm', 'skew']
# ----------- Total 0.09 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.17 sec.
# Plane 0 processed in 2478.28 sec (can open in GUI).
# total = 3523.83 sec.
# TOTAL RUNTIME 3523.83 sec
# {'date': '15_12_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 5}
# 0 1000
# 1000 2000
# 2000 3000
# 3000 4000
# 4000 5000
# 5000 6000
