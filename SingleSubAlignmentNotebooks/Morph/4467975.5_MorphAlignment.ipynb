# %%
import numpy as np
import scipy as sp
import suite2p as s2p
import TwoPUtils
import os
from matplotlib import pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
write_folder = os.path.join('/home','mplitt','2P_scratch')


mouse = '4467975.5'

file_list = ({'date': '09_10_2020', 'scene':'TwoTower_foraging','session':3,'scan':9},
             {'date': '11_10_2020', 'scene':'TwoTower_foraging','session':3,'scan':5},
             {'date': '13_10_2020', 'scene':'TwoTower_foraging','session':2,'scan':5},
             {'date': '14_10_2020', 'scene':'TwoTower_foraging','session':2,'scan':4},
             {'date': '15_10_2020', 'scene':'TwoTower_foraging','session':2,'scan':3},
             {'date': '16_10_2020', 'scene':'TwoTower_foraging','session':2,'scan':3},
             #{'date': '17_10_2020', 'scene':'TwoTower_foraging','session':2,'scan':4},
             #{'date': '17_10_2020', 'scene':'TwoTower_foraging','session':4,'scan':9}, # dendrites
             )

# %%
def check_and_make_h5s(file_list, runh5=True):
    h5list, framerates = [], []
    for f in file_list:
        print(f)
        scan_str = "%s_%03d_%03d" % (f['scene'],f['session'],f['scan'])
        try:
            source_folder  = os.path.join('/media','mplitt','Backup Plus','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        except:
            source_folder  = os.path.join('/media','mplitt','Backup Plus1','2P_Data')
            source_stem = os.path.join(source_folder,mouse,f['date'],f['scene'],scan_str)
            info = TwoPUtils.scanner_tools.sbx_utils.loadmat(source_stem+'.mat')
        
        file_stem = os.path.join(write_folder,mouse,f['date'],f['scene'],scan_str)
        h5path = os.path.join(file_stem,scan_str+".h5")
        if not os.path.exists(h5path) and runh5:
            _ = TwoPUtils.scanner_tools.sbx_utils.sbx2h5(source_stem,output_name=h5path,force_2chan=True)

        h5list.append(file_stem)
        framerates.append(info['frame_rate'])
    print(h5list)
    return h5list, framerates

# %%
for f in file_list:
    _h5list,_frs = check_and_make_h5s([f,],runh5=False)
    ops = TwoPUtils.s2p.set_ops(d={'data_path': _h5list,
                                   'save_path0': _h5list[0],
                                    'fast_disk':[],
                                    'move_bin':True,
                                    'two_step_registration':True,
                                    'maxregshiftNR':10,
                                    'nchannels':2,
                                    'tau':.7,
                                    'functional_chan':1,
                                    'fs':_frs[0],
                                    'roidetect':True,
                                    'input_format':"h5",
                                    'h5py_key':'data',
                                    'nchannels':2,
                                    'threshold_scaling':2.0,
                                    'chan2_thresh':.01})
    ops=s2p.run_s2p(ops=ops)
    # !rm {_h5list[0]}/*.h5
# Out:
# {'date': '09_10_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 9}
# ['/home/mplitt/2P_scratch/4467975.5/09_10_2020/TwoTower_foraging/TwoTower_foraging_003_009']
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/4467975.5/09_10_2020/TwoTower_foraging/TwoTower_foraging_003_009/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1845,416,698], 40.47 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 1.54, threshold 15.38
# 0 ROIs, score=331.84
# 1000 ROIs, score=62.59
# 2000 ROIs, score=35.36
# 3000 ROIs, score=20.88
# Found 3548 ROIs, 64.98 sec
# After removing overlaps, 3004 ROIs remain
# Masks made in 101.53 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 319.67 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 3004 ROIs in 20710 frames, 84.15 sec.
# Extracted fluorescence from 3004 ROIs in 20710 frames, 84.75 sec.
# added enhanced mean image
# ----------- Total 174.35 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.28 sec.
# Plane 0 processed in 497.65 sec (can open in GUI).
# total = 499.04 sec.
# TOTAL RUNTIME 499.04 sec
# rm: cannot remove '/home/mplitt/2P_scratch/4467975.5/09_10_2020/TwoTower_foraging/TwoTower_foraging_003_009/*.h5': No such file or directory
# {'date': '11_10_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 5}
# ['/home/mplitt/2P_scratch/4467975.5/11_10_2020/TwoTower_foraging/TwoTower_foraging_003_005']
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/4467975.5/11_10_2020/TwoTower_foraging/TwoTower_foraging_003_005/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [1574,416,694], 34.53 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 1.31, threshold 13.12
# 0 ROIs, score=273.55
# 1000 ROIs, score=54.03
# 2000 ROIs, score=26.64
# Found 2954 ROIs, 49.26 sec
# After removing overlaps, 2488 ROIs remain
# Masks made in 77.33 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 248.01 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2488 ROIs in 17667 frames, 64.90 sec.
# Extracted fluorescence from 2488 ROIs in 17667 frames, 65.52 sec.
# added enhanced mean image
# ----------- Total 135.47 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.06 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 2.34 sec.
# Plane 0 processed in 386.10 sec (can open in GUI).
# total = 387.43 sec.
# TOTAL RUNTIME 387.43 sec
# rm: cannot remove '/home/mplitt/2P_scratch/4467975.5/11_10_2020/TwoTower_foraging/TwoTower_foraging_003_005/*.h5': No such file or directory
# {'date': '13_10_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 5}
# ['/home/mplitt/2P_scratch/4467975.5/13_10_2020/TwoTower_foraging/TwoTower_foraging_002_005']
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/4467975.5/13_10_2020/TwoTower_foraging/TwoTower_foraging_002_005/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2250,416,694], 49.91 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 1.88, threshold 18.75
# 0 ROIs, score=345.46
# 1000 ROIs, score=68.04
# 2000 ROIs, score=30.98
# Found 2641 ROIs, 68.98 sec
# After removing overlaps, 2322 ROIs remain
# Masks made in 82.30 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 293.75 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2322 ROIs in 25003 frames, 89.85 sec.
# Extracted fluorescence from 2322 ROIs in 25003 frames, 89.66 sec.
# added enhanced mean image
# ----------- Total 184.81 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.17 sec.
# Plane 0 processed in 482.05 sec (can open in GUI).
# total = 483.50 sec.
# TOTAL RUNTIME 483.50 sec
# rm: cannot remove '/home/mplitt/2P_scratch/4467975.5/13_10_2020/TwoTower_foraging/TwoTower_foraging_002_005/*.h5': No such file or directory
# {'date': '14_10_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 4}
# ['/home/mplitt/2P_scratch/4467975.5/14_10_2020/TwoTower_foraging/TwoTower_foraging_002_004']
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/4467975.5/14_10_2020/TwoTower_foraging/TwoTower_foraging_002_004/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [3284,416,694], 72.56 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 2.74, threshold 27.37
# 0 ROIs, score=500.42
# 1000 ROIs, score=93.07
# 2000 ROIs, score=53.35
# 3000 ROIs, score=32.20
# Found 3296 ROIs, 105.64 sec
# After removing overlaps, 2844 ROIs remain
# Masks made in 96.58 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 382.92 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2844 ROIs in 36843 frames, 146.85 sec.
# Extracted fluorescence from 2844 ROIs in 36843 frames, 146.72 sec.
# added enhanced mean image
# ----------- Total 299.82 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 5.47 sec.
# Plane 0 processed in 688.78 sec (can open in GUI).
# total = 690.33 sec.
# TOTAL RUNTIME 690.33 sec
# rm: cannot remove '/home/mplitt/2P_scratch/4467975.5/14_10_2020/TwoTower_foraging/TwoTower_foraging_002_004/*.h5': No such file or directory
# {'date': '15_10_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# ['/home/mplitt/2P_scratch/4467975.5/15_10_2020/TwoTower_foraging/TwoTower_foraging_002_003']
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/4467975.5/15_10_2020/TwoTower_foraging/TwoTower_foraging_002_003/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2204,416,694], 49.48 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 1.84, threshold 18.37
# 0 ROIs, score=326.71
# 1000 ROIs, score=73.62
# 2000 ROIs, score=39.57
# 3000 ROIs, score=21.67
# Found 3294 ROIs, 77.12 sec
# After removing overlaps, 2718 ROIs remain
# Masks made in 108.74 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 353.95 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2718 ROIs in 24872 frames, 95.53 sec.
# Extracted fluorescence from 2718 ROIs in 24872 frames, 96.76 sec.
# added enhanced mean image
# ----------- Total 197.82 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.57 sec.
# Plane 0 processed in 555.72 sec (can open in GUI).
# total = 557.16 sec.
# TOTAL RUNTIME 557.16 sec
# rm: cannot remove '/home/mplitt/2P_scratch/4467975.5/15_10_2020/TwoTower_foraging/TwoTower_foraging_002_003/*.h5': No such file or directory
# {'date': '16_10_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# ['/home/mplitt/2P_scratch/4467975.5/16_10_2020/TwoTower_foraging/TwoTower_foraging_002_003']
# {}
# FOUND BINARIES AND OPS IN ['/home/mplitt/2P_scratch/4467975.5/16_10_2020/TwoTower_foraging/TwoTower_foraging_002_003/suite2p/plane0/ops.npy']
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# NOTE: not running registration, plane already registered
# NOTE: applying default /home/mplitt/.suite2p/classifiers/classifier_user.npy
# ----------- ROI DETECTION
# Binning movie in chunks of length 11
# Binned movie [2385,418,694], 52.44 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 1.99, threshold 19.88
# 0 ROIs, score=383.60
# 1000 ROIs, score=73.79
# 2000 ROIs, score=38.57
# 3000 ROIs, score=21.33
# Found 3117 ROIs, 79.56 sec
# After removing overlaps, 2636 ROIs remain
# Masks made in 96.91 sec.
# >>>> CELLPOSE estimating masks in anatomical channel
# ERROR importing or running cellpose, continuing without anatomical estimates
# ----------- Total 335.56 sec.
# ----------- EXTRACTION
# Extracted fluorescence from 2636 ROIs in 26702 frames, 102.92 sec.
# Extracted fluorescence from 2636 ROIs in 26702 frames, 102.94 sec.
# added enhanced mean image
# ----------- Total 211.43 sec.
# ----------- CLASSIFICATION
# ['skew', 'npix_norm', 'compact']
# ----------- Total 0.05 sec.
# ----------- SPIKE DECONVOLUTION
# ----------- Total 3.70 sec.
# Plane 0 processed in 551.08 sec (can open in GUI).
# total = 552.55 sec.
# TOTAL RUNTIME 552.55 sec
# rm: cannot remove '/home/mplitt/2P_scratch/4467975.5/16_10_2020/TwoTower_foraging/TwoTower_foraging_002_003/*.h5': No such file or directory
